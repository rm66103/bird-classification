# %%
# Load environment variables from .env file
from dotenv import load_dotenv
load_dotenv()

# Import the XenoCanto service
import sys
sys.path.append('..')
from services.xeno_canto_service import XenoCantoService

# Initialize the service (will read API key from environment)
service = XenoCantoService()

# Make a simple test API call - get 1 recording of American Robin
print("Testing Xeno-canto API connection...")
result = service.search_recordings(
    species_common_name="American Robin",
    quality="A",  # High quality recordings only
    per_page=50,
    page=1
)

if result:
    print(f"\n✅ API connection successful!")
    print(f"Total recordings found: {result.get('numRecordings', 0)}")
    print(f"Total species: {result.get('numSpecies', 0)}")
    
    if result.get('recordings'):
        recording = result['recordings'][0]
        print(f"\n📊 Sample Recording:")
        print(f"  ID: {recording.get('id')}")
        print(f"  Species: {recording.get('gen')} {recording.get('sp')}")
        print(f"  Common Name: {recording.get('en')}")
        print(f"  Quality: {recording.get('q')}")
        print(f"  Location: {recording.get('loc', 'N/A')}")
        print(f"  Country: {recording.get('cnt', 'N/A')}")
        print(f"  Duration: {recording.get('length', 'N/A')}")
        print(f"  Audio URL: {recording.get('file', 'N/A')}")
    else:
        print("\n⚠️ No recordings found in response")
else:
    print("\n❌ API request failed")
# Out:
# Testing Xeno-canto API connection...
#
# ✅ API connection successful!
# Total recordings found: 314
# Total species: 1
#
# 📊 Sample Recording:
#   ID: 1068477
#   Species: Turdus migratorius
#   Common Name: American Robin
#   Quality: A
#   Location: Swan Lake Park, Regional Municipality of York, Ontario
#   Country: Canada
#   Duration: 0:56
#   Audio URL: https://xeno-canto.org/1068477/download

# %%
# Import additional services and libraries
import json
import pandas as pd
import requests
from pathlib import Path
import time
from typing import Dict, List, Optional
import tempfile
import os

from services.s3_manager import S3Manager

# Load species configuration
with open('../config/species_config.json', 'r') as f:
    species_config = json.load(f)

georgia_birds = species_config['georgia_birds']
print(f"Loaded {len(georgia_birds)} Georgia bird species:")
for bird in georgia_birds:
    print(f"  - {bird['common_name']} ({bird['scientific_name']})")

# Initialize S3 Manager
s3_manager = S3Manager(create_bucket_if_not_exists=True)
print(f"\n✅ S3 Manager initialized for bucket: {s3_manager.bucket_name}")
# Out:
# /var/folders/wc/js21wthx2f33wln3fbvy9shm0000gn/T/ipykernel_87982/4266994096.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Loaded 8 Georgia bird species:
#   - Northern Cardinal (Cardinalis cardinalis)
#   - Carolina Wren (Thryothorus ludovicianus)
#   - Blue Jay (Cyanocitta cristata)
#   - American Robin (Turdus migratorius)
#   - Mourning Dove (Zenaida macroura)
#   - Tufted Titmouse (Baeolophus bicolor)
#   - Carolina Chickadee (Poecile carolinensis)
#   - Eastern Bluebird (Sialia sialis)
#
# ✅ S3 Manager initialized for bucket: bird-classification-data

# %%
# Helper Functions

def download_audio_file(url: str, local_path: str, max_retries: int = 3, timeout: int = 30) -> bool:
    """
    Download an audio file with retry logic.
    
    Args:
        url: URL of the audio file to download
        local_path: Local file path to save the download
        max_retries: Maximum number of retry attempts
        timeout: Request timeout in seconds
    
    Returns:
        True if download successful, False otherwise
    """
    # Fix URL format - handle various malformed URL patterns
    # Check for well-formed URLs first
    if url.startswith('https://') or url.startswith('http://'):
        # Already well-formed, no changes needed
        pass
    elif url.startswith('https:https://'):
        url = url.replace('https:https://', 'https://')
    elif url.startswith('https:////'):
        url = url.replace('https:////', 'https://')
    elif url.startswith('https:'):
        # Missing second slash: https:domain.com -> https://domain.com
        url = url.replace('https:', 'https://', 1)  # Replace only first occurrence
    elif url.startswith('//'):
        # Protocol-relative URL - add https:
        url = 'https:' + url
    else:
        # Assume it needs https:// prefix
        url = f"https://{url}"
    
    # Create directory if it doesn't exist
    Path(local_path).parent.mkdir(parents=True, exist_ok=True)
    
    for attempt in range(max_retries):
        try:
            response = requests.get(url, timeout=timeout, stream=True)
            response.raise_for_status()
            
            with open(local_path, 'wb') as f:
                for chunk in response.iter_content(chunk_size=8192):
                    f.write(chunk)
            
            return True
        except Exception as e:
            if attempt < max_retries - 1:
                wait_time = 2 ** attempt  # Exponential backoff
                print(f"  Retry {attempt + 1}/{max_retries} after {wait_time}s...")
                time.sleep(wait_time)
            else:
                print(f"  Failed to download after {max_retries} attempts: {e}")
                return False
    
    return False

def normalize_metadata(recording_data: Dict, species_common_name: str, species_scientific_name: str, s3_uri: Optional[str] = None) -> Dict:
    """
    Normalize recording metadata to standardized format.
    
    Args:
        recording_data: Raw recording data from Xeno-canto API
        species_common_name: Common name of the species
        species_scientific_name: Scientific name of the species
        s3_uri: S3 URI of the uploaded audio file (if available)
    
    Returns:
        Normalized metadata dictionary
    """
    # Parse duration (format: "M:SS" or "MM:SS")
    duration_str = recording_data.get('length', '0:00')
    duration_seconds = 0
    try:
        parts = duration_str.split(':')
        if len(parts) == 2:
            duration_seconds = int(parts[0]) * 60 + int(parts[1])
    except:
        pass
    
    # Build Xeno-canto URL
    recording_id = recording_data.get('id', '')
    xeno_canto_url = f"https://xeno-canto.org/{recording_id}" if recording_id else ""
    
    return {
        'recording_id': recording_id,
        'species_common_name': species_common_name,
        'species_scientific_name': species_scientific_name,
        'audio_s3_uri': s3_uri or '',
        'recording_quality': recording_data.get('q', ''),
        'duration_seconds': duration_seconds,
        'duration_formatted': duration_str,
        'location': recording_data.get('loc', ''),
        'country': recording_data.get('cnt', ''),
        'date': recording_data.get('date', ''),
        'xeno_canto_url': xeno_canto_url,
        'genus': recording_data.get('gen', ''),
        'species': recording_data.get('sp', ''),
        'file_url': recording_data.get('file', '')
    }

print("✅ Helper functions defined")
# Out:
# ✅ Helper functions defined

# %%
# Main Acquisition Pipeline

def process_species(
    species_common_name: str,
    species_scientific_name: str,
    max_recordings: int = 100,
    quality_filter: str = "A",
    temp_dir: str = "/tmp/bird_recordings"
) -> List[Dict]:
    """
    Process a single species: query API, download recordings, upload to S3.
    
    Args:
        species_common_name: Common name of the species
        species_scientific_name: Scientific name of the species
        max_recordings: Maximum number of recordings to process
        quality_filter: Quality filter (e.g., "A" for high quality)
        temp_dir: Temporary directory for downloads
    
    Returns:
        List of normalized metadata dictionaries
    """
    print(f"\n{'='*60}")
    print(f"Processing: {species_common_name} ({species_scientific_name})")
    print(f"{'='*60}")
    
    # Create temp directory for this species
    species_temp_dir = Path(temp_dir) / species_common_name.replace(' ', '_')
    species_temp_dir.mkdir(parents=True, exist_ok=True)
    
    # Query API for recordings
    print(f"Querying Xeno-canto API...")
    recordings = service.get_all_recordings_for_species(
        species_common_name=species_common_name,
        quality=quality_filter,
        max_recordings=max_recordings,
        per_page=100
    )
    
    if not recordings:
        print(f"⚠️ No recordings found for {species_common_name}")
        return []
    
    print(f"Found {len(recordings)} recordings")
    
    # Process each recording
    metadata_list = []
    successful_downloads = 0
    failed_downloads = 0
    
    for idx, recording in enumerate(recordings, 1):
        recording_id = recording.get('id', 'unknown')
        file_url = recording.get('file', '')
        
        if not file_url:
            print(f"  [{idx}/{len(recordings)}] Skipping {recording_id}: No file URL")
            failed_downloads += 1
            continue
        
        # Fix URL format - handle various API response formats
        if file_url.startswith('https://'):
            audio_url = file_url
        elif file_url.startswith('//'):
            # Protocol-relative URL - add https:
            audio_url = 'https:' + file_url
        elif file_url.startswith('http://'):
            audio_url = file_url
        else:
            # Assume it's a relative path or domain - prepend https://
            audio_url = f"https://{file_url}"
        
        # Download audio file
        local_file = species_temp_dir / f"{recording_id}.mp3"
        print(f"  [{idx}/{len(recordings)}] Downloading {recording_id}...", end=' ')
        
        if download_audio_file(audio_url, str(local_file)):
            # Upload to S3
            s3_uri = s3_manager.upload_audio_file(
                str(local_file),
                species_common_name,
                recording_id
            )
            
            if s3_uri:
                # Normalize metadata
                metadata = normalize_metadata(
                    recording,
                    species_common_name,
                    species_scientific_name,
                    s3_uri
                )
                metadata_list.append(metadata)
                successful_downloads += 1
                print(f"✅ Uploaded to S3")
            else:
                print(f"❌ S3 upload failed")
                failed_downloads += 1
            
            # Clean up local file
            local_file.unlink()
        else:
            failed_downloads += 1
            print(f"❌ Download failed")
    
    print(f"\nSummary for {species_common_name}:")
    print(f"  ✅ Successful: {successful_downloads}")
    print(f"  ❌ Failed: {failed_downloads}")
    print(f"  📊 Total metadata entries: {len(metadata_list)}")
    
    return metadata_list

print("✅ Process function defined")
# Out:
# ✅ Process function defined

# %%
# Run acquisition pipeline for all species

all_metadata = []
errors = []

# Configuration
MAX_RECORDINGS_PER_SPECIES = 100
QUALITY_FILTER = "A"  # High quality recordings only

print(f"Starting acquisition pipeline...")
print(f"Target: {MAX_RECORDINGS_PER_SPECIES} recordings per species")
print(f"Quality filter: {QUALITY_FILTER}")
print(f"Total species: {len(georgia_birds)}\n")

for bird in georgia_birds:
    try:
        metadata = process_species(
            species_common_name=bird['common_name'],
            species_scientific_name=bird['scientific_name'],
            max_recordings=MAX_RECORDINGS_PER_SPECIES,
            quality_filter=QUALITY_FILTER
        )
        all_metadata.extend(metadata)
    except Exception as e:
        error_msg = f"Error processing {bird['common_name']}: {e}"
        print(f"❌ {error_msg}")
        errors.append(error_msg)

print(f"\n{'='*60}")
print(f"Pipeline Complete!")
print(f"{'='*60}")
print(f"Total recordings processed: {len(all_metadata)}")
print(f"Total errors: {len(errors)}")

if errors:
    print(f"\nErrors encountered:")
    for error in errors:
        print(f"  - {error}")
# Out:
# Starting acquisition pipeline...
# Target: 100 recordings per species
# Quality filter: A
# Total species: 8
#
#
# ============================================================
# Processing: Northern Cardinal (Cardinalis cardinalis)
# ============================================================
# Querying Xeno-canto API...
# Found 100 recordings
#   [1/100] Downloading 1070756... ✅ Uploaded to S3
#   [2/100] Downloading 1070366... ✅ Uploaded to S3
#   [3/100] Downloading 1027842... ✅ Uploaded to S3
#   [4/100] Downloading 1012918... ✅ Uploaded to S3
#   [5/100] Downloading 1012917... ✅ Uploaded to S3
#   [6/100] Downloading 1012916... ✅ Uploaded to S3
#   [7/100] Downloading 1012495... ✅ Uploaded to S3
#   [8/100] Downloading 1012494... ✅ Uploaded to S3
#   [9/100] Downloading 1012493... ✅ Uploaded to S3
#   [10/100] Downloading 1012492... ✅ Uploaded to S3
#   [11/100] Downloading 1012491... ✅ Uploaded to S3
#   [12/100] Downloading 1012142... ✅ Uploaded to S3
#   [13/100] Downloading 1010649... ✅ Uploaded to S3
#   [14/100] Downloading 1010609... ✅ Uploaded to S3
#   [15/100] Downloading 1006772... ✅ Uploaded to S3
#   [16/100] Downloading 1000327... ✅ Uploaded to S3
#   [17/100] Downloading 1000248... ✅ Uploaded to S3
#   [18/100] Downloading 995475... ✅ Uploaded to S3
#   [19/100] Downloading 984331... ✅ Uploaded to S3
#   [20/100] Downloading 962371... ✅ Uploaded to S3
#   [21/100] Downloading 952632... ✅ Uploaded to S3
#   [22/100] Downloading 941475... ✅ Uploaded to S3
#   [23/100] Downloading 931722... ✅ Uploaded to S3
#   [24/100] Downloading 931717... ✅ Uploaded to S3
#   [25/100] Downloading 931709... ✅ Uploaded to S3
#   [26/100] Downloading 931706... ✅ Uploaded to S3
#   [27/100] Downloading 931704... ✅ Uploaded to S3
#   [28/100] Downloading 930723... ✅ Uploaded to S3
#   [29/100] Downloading 920145... ✅ Uploaded to S3
#   [30/100] Downloading 920144... ✅ Uploaded to S3
#   [31/100] Downloading 899257... ✅ Uploaded to S3
#   [32/100] Downloading 899256... ✅ Uploaded to S3
#   [33/100] Downloading 899245... ✅ Uploaded to S3
#   [34/100] Downloading 894710... ✅ Uploaded to S3
#   [35/100] Downloading 879106... ✅ Uploaded to S3
#   [36/100] Downloading 877641... ✅ Uploaded to S3
#   [37/100] Downloading 872638... ✅ Uploaded to S3
#   [38/100] Downloading 872098... ✅ Uploaded to S3
#   [39/100] Downloading 870690... ✅ Uploaded to S3
#   [40/100] Downloading 858755... ✅ Uploaded to S3
#   [41/100] Downloading 812577... ✅ Uploaded to S3
#   [42/100] Downloading 809789... ✅ Uploaded to S3
#   [43/100] Downloading 799143... ✅ Uploaded to S3
#   [44/100] Downloading 797998... ✅ Uploaded to S3
#   [45/100] Downloading 796781... ✅ Uploaded to S3
#   [46/100] Downloading 793701... ✅ Uploaded to S3
#   [47/100] Downloading 792359... ✅ Uploaded to S3
#   [48/100] Downloading 792208... ✅ Uploaded to S3
#   [49/100] Downloading 791092... ✅ Uploaded to S3
#   [50/100] Downloading 788188... ✅ Uploaded to S3
#   [51/100] Downloading 786107... ✅ Uploaded to S3
#   [52/100] Downloading 781949... ✅ Uploaded to S3
#   [53/100] Downloading 779378... ✅ Uploaded to S3
#   [54/100] Downloading 778522... ✅ Uploaded to S3
#   [55/100] Downloading 764941... ✅ Uploaded to S3
#   [56/100] Downloading 764938... ✅ Uploaded to S3
#   [57/100] Downloading 759257... ✅ Uploaded to S3
#   [58/100] Downloading 759255... ✅ Uploaded to S3
#   [59/100] Downloading 759248... ✅ Uploaded to S3
#   [60/100] Downloading 743545... ✅ Uploaded to S3
#   [61/100] Downloading 742592... ✅ Uploaded to S3
#   [62/100] Downloading 742591... ✅ Uploaded to S3
#   [63/100] Downloading 742012... ✅ Uploaded to S3
#   [64/100] Downloading 740407... ✅ Uploaded to S3
#   [65/100] Downloading 738697... ✅ Uploaded to S3
#   [66/100] Downloading 738212... ✅ Uploaded to S3
#   [67/100] Downloading 730976... ✅ Uploaded to S3
#   [68/100] Downloading 727761... ✅ Uploaded to S3
#   [69/100] Downloading 725630... ✅ Uploaded to S3
#   [70/100] Downloading 725506... ✅ Uploaded to S3
#   [71/100] Downloading 725505... ✅ Uploaded to S3
#   [72/100] Downloading 725504... ✅ Uploaded to S3
#   [73/100] Downloading 725495... ✅ Uploaded to S3
#   [74/100] Downloading 721721... ✅ Uploaded to S3
#   [75/100] Downloading 720913... ✅ Uploaded to S3
#   [76/100] Downloading 718207... ✅ Uploaded to S3
#   [77/100] Downloading 718197... ✅ Uploaded to S3
#   [78/100] Downloading 718194... ✅ Uploaded to S3
#   [79/100] Downloading 718150... ✅ Uploaded to S3
#   [80/100] Downloading 718119... ✅ Uploaded to S3
#   [81/100] Downloading 717104... ✅ Uploaded to S3
#   [82/100] Downloading 716618... ✅ Uploaded to S3
#   [83/100] Downloading 713583... ✅ Uploaded to S3
#   [84/100] Downloading 709562... ✅ Uploaded to S3
#   [85/100] Downloading 708834... ✅ Uploaded to S3
#   [86/100] Downloading 707383... ✅ Uploaded to S3
#   [87/100] Downloading 696751... ✅ Uploaded to S3
#   [88/100] Downloading 691763... ✅ Uploaded to S3
#   [89/100] Downloading 682547... ✅ Uploaded to S3
#   [90/100] Downloading 681641... ✅ Uploaded to S3
#   [91/100] Downloading 677300... ✅ Uploaded to S3
#   [92/100] Downloading 667645... ✅ Uploaded to S3
#   [93/100] Downloading 652980... ✅ Uploaded to S3
#   [94/100] Downloading 649276... ✅ Uploaded to S3
#   [95/100] Downloading 649261... ✅ Uploaded to S3
#   [96/100] Downloading 642029... ✅ Uploaded to S3
#   [97/100] Downloading 639161... ✅ Uploaded to S3
#   [98/100] Downloading 639160... ✅ Uploaded to S3
#   [99/100] Downloading 636561... ✅ Uploaded to S3
#   [100/100] Downloading 636560... ✅ Uploaded to S3
#
# Summary for Northern Cardinal:
#   ✅ Successful: 100
#   ❌ Failed: 0
#   📊 Total metadata entries: 100
#
# ============================================================
# Processing: Carolina Wren (Thryothorus ludovicianus)
# ============================================================
# Querying Xeno-canto API...
# Found 100 recordings
#   [1/100] Downloading 1035997... ✅ Uploaded to S3
#   [2/100] Downloading 1010648... ✅ Uploaded to S3
#   [3/100] Downloading 1004463... ✅ Uploaded to S3
#   [4/100] Downloading 995314... ✅ Uploaded to S3
#   [5/100] Downloading 951785... ✅ Uploaded to S3
#   [6/100] Downloading 951784... ✅ Uploaded to S3
#   [7/100] Downloading 951783... ✅ Uploaded to S3
#   [8/100] Downloading 951782... ✅ Uploaded to S3
#   [9/100] Downloading 951781... ✅ Uploaded to S3
#   [10/100] Downloading 941065... ✅ Uploaded to S3
#   [11/100] Downloading 938797... ✅ Uploaded to S3
#   [12/100] Downloading 929922... ✅ Uploaded to S3
#   [13/100] Downloading 923843... ✅ Uploaded to S3
#   [14/100] Downloading 923842... ✅ Uploaded to S3
#   [15/100] Downloading 923841... ✅ Uploaded to S3
#   [16/100] Downloading 923840... ✅ Uploaded to S3
#   [17/100] Downloading 923839... ✅ Uploaded to S3
#   [18/100] Downloading 923838... ✅ Uploaded to S3
#   [19/100] Downloading 923837... ✅ Uploaded to S3
#   [20/100] Downloading 923836... ✅ Uploaded to S3
#   [21/100] Downloading 923835... ✅ Uploaded to S3
#   [22/100] Downloading 905700... ✅ Uploaded to S3
#   [23/100] Downloading 900263... ✅ Uploaded to S3
#   [24/100] Downloading 899254... ✅ Uploaded to S3
#   [25/100] Downloading 899252... ✅ Uploaded to S3
#   [26/100] Downloading 896572... ✅ Uploaded to S3
#   [27/100] Downloading 893182... ✅ Uploaded to S3
#   [28/100] Downloading 884090... ✅ Uploaded to S3
#   [29/100] Downloading 880326... ✅ Uploaded to S3
#   [30/100] Downloading 880323... ✅ Uploaded to S3
#   [31/100] Downloading 879133... ✅ Uploaded to S3
#   [32/100] Downloading 855744... ✅ Uploaded to S3
#   [33/100] Downloading 842981... ✅ Uploaded to S3
#   [34/100] Downloading 840733... ✅ Uploaded to S3
#   [35/100] Downloading 828442... ✅ Uploaded to S3
#   [36/100] Downloading 828436... ✅ Uploaded to S3
#   [37/100] Downloading 828415... ✅ Uploaded to S3
#   [38/100] Downloading 820851... ✅ Uploaded to S3
#   [39/100] Downloading 805390... ✅ Uploaded to S3
#   [40/100] Downloading 803581... ✅ Uploaded to S3
#   [41/100] Downloading 793225... ✅ Uploaded to S3
#   [42/100] Downloading 792591... ✅ Uploaded to S3
#   [43/100] Downloading 792351... ✅ Uploaded to S3
#   [44/100] Downloading 738783... ✅ Uploaded to S3
#   [45/100] Downloading 735870... ✅ Uploaded to S3
#   [46/100] Downloading 729229... ✅ Uploaded to S3
#   [47/100] Downloading 723565... ✅ Uploaded to S3
#   [48/100] Downloading 723375... ✅ Uploaded to S3
#   [49/100] Downloading 723309... ✅ Uploaded to S3
#   [50/100] Downloading 713786... ✅ Uploaded to S3
#   [51/100] Downloading 703720... ✅ Uploaded to S3
#   [52/100] Downloading 692428... ✅ Uploaded to S3
#   [53/100] Downloading 692426... ✅ Uploaded to S3
#   [54/100] Downloading 683969... ✅ Uploaded to S3
#   [55/100] Downloading 682561... ✅ Uploaded to S3
#   [56/100] Downloading 682556... ✅ Uploaded to S3
#   [57/100] Downloading 682555... ✅ Uploaded to S3
#   [58/100] Downloading 668895... ✅ Uploaded to S3
#   [59/100] Downloading 668894... ✅ Uploaded to S3
#   [60/100] Downloading 667670...   Retry 1/3 after 1s...
#   Retry 2/3 after 2s...
#   Failed to download after 3 attempts: HTTPSConnectionPool(host='xeno-canto.org', port=443): Read timed out. (read timeout=30)
# ❌ Download failed
#   [61/100] Downloading 655937...   Retry 1/3 after 1s...
# ✅ Uploaded to S3
#   [62/100] Downloading 654818... ✅ Uploaded to S3
#   [63/100] Downloading 637178... ✅ Uploaded to S3
#   [64/100] Downloading 601159... ✅ Uploaded to S3
#   [65/100] Downloading 600722... ✅ Uploaded to S3
#   [66/100] Downloading 600422... ✅ Uploaded to S3
#   [67/100] Downloading 598822... ✅ Uploaded to S3
#   [68/100] Downloading 593815... ✅ Uploaded to S3
#   [69/100] Downloading 585721... ✅ Uploaded to S3
#   [70/100] Downloading 583926... ✅ Uploaded to S3
#   [71/100] Downloading 581488... ✅ Uploaded to S3
#   [72/100] Downloading 578525... ✅ Uploaded to S3
#   [73/100] Downloading 574085... ✅ Uploaded to S3
#   [74/100] Downloading 573676... ✅ Uploaded to S3
#   [75/100] Downloading 572229... ✅ Uploaded to S3
#   [76/100] Downloading 572226... ✅ Uploaded to S3
#   [77/100] Downloading 572160... ✅ Uploaded to S3
#   [78/100] Downloading 570954... ✅ Uploaded to S3
#   [79/100] Downloading 570651... ✅ Uploaded to S3
#   [80/100] Downloading 570326... ✅ Uploaded to S3
#   [81/100] Downloading 569714... ✅ Uploaded to S3
#   [82/100] Downloading 569632... ✅ Uploaded to S3
#   [83/100] Downloading 569631... ✅ Uploaded to S3
#   [84/100] Downloading 568353... ✅ Uploaded to S3
#   [85/100] Downloading 567330... ✅ Uploaded to S3
#   [86/100] Downloading 564323... ✅ Uploaded to S3
#   [87/100] Downloading 564322... ✅ Uploaded to S3
#   [88/100] Downloading 564318... ✅ Uploaded to S3
#   [89/100] Downloading 563816... ✅ Uploaded to S3
#   [90/100] Downloading 563616... ✅ Uploaded to S3
#   [91/100] Downloading 563615... ✅ Uploaded to S3
#   [92/100] Downloading 563611... ✅ Uploaded to S3
#   [93/100] Downloading 563199... ✅ Uploaded to S3
#   [94/100] Downloading 562224... ✅ Uploaded to S3
#   [95/100] Downloading 562223... ✅ Uploaded to S3
#   [96/100] Downloading 562219... ✅ Uploaded to S3
#   [97/100] Downloading 558225... ✅ Uploaded to S3
#   [98/100] Downloading 556688... ✅ Uploaded to S3
#   [99/100] Downloading 556632... ✅ Uploaded to S3
#   [100/100] Downloading 556631... ✅ Uploaded to S3
#
# Summary for Carolina Wren:
#   ✅ Successful: 99
#   ❌ Failed: 1
#   📊 Total metadata entries: 99
#
# ============================================================
# Processing: Blue Jay (Cyanocitta cristata)
# ============================================================
# Querying Xeno-canto API...
# Found 100 recordings
#   [1/100] Downloading 1059662... ✅ Uploaded to S3
#   [2/100] Downloading 1051304... ✅ Uploaded to S3
#   [3/100] Downloading 1046664... ✅ Uploaded to S3
#   [4/100] Downloading 1038505... ✅ Uploaded to S3
#   [5/100] Downloading 1036141... ✅ Uploaded to S3
#   [6/100] Downloading 1020596... ✅ Uploaded to S3
#   [7/100] Downloading 1014208... ✅ Uploaded to S3
#   [8/100] Downloading 1013391... ✅ Uploaded to S3
#   [9/100] Downloading 1013390... ✅ Uploaded to S3
#   [10/100] Downloading 1012557... ✅ Uploaded to S3
#   [11/100] Downloading 1012556... ✅ Uploaded to S3
#   [12/100] Downloading 1012555... ✅ Uploaded to S3
#   [13/100] Downloading 1010650... ✅ Uploaded to S3
#   [14/100] Downloading 1007688... ✅ Uploaded to S3
#   [15/100] Downloading 994294... ✅ Uploaded to S3
#   [16/100] Downloading 980359... ✅ Uploaded to S3
#   [17/100] Downloading 958098... ✅ Uploaded to S3
#   [18/100] Downloading 940085... ✅ Uploaded to S3
#   [19/100] Downloading 938988... ✅ Uploaded to S3
#   [20/100] Downloading 937346... ✅ Uploaded to S3
#   [21/100] Downloading 935610... ✅ Uploaded to S3
#   [22/100] Downloading 935607... ✅ Uploaded to S3
#   [23/100] Downloading 933597... ✅ Uploaded to S3
#   [24/100] Downloading 933596... ✅ Uploaded to S3
#   [25/100] Downloading 933595... ✅ Uploaded to S3
#   [26/100] Downloading 925282... ✅ Uploaded to S3
#   [27/100] Downloading 924514... ✅ Uploaded to S3
#   [28/100] Downloading 924410... ✅ Uploaded to S3
#   [29/100] Downloading 908392... ✅ Uploaded to S3
#   [30/100] Downloading 906702... ✅ Uploaded to S3
#   [31/100] Downloading 899923... ✅ Uploaded to S3
#   [32/100] Downloading 880466... ✅ Uploaded to S3
#   [33/100] Downloading 861979... ✅ Uploaded to S3
#   [34/100] Downloading 841327... ✅ Uploaded to S3
#   [35/100] Downloading 839184... ✅ Uploaded to S3
#   [36/100] Downloading 833840... ✅ Uploaded to S3
#   [37/100] Downloading 817559... ✅ Uploaded to S3
#   [38/100] Downloading 817558... ✅ Uploaded to S3
#   [39/100] Downloading 817557... ✅ Uploaded to S3
#   [40/100] Downloading 817555... ✅ Uploaded to S3
#   [41/100] Downloading 809927... ✅ Uploaded to S3
#   [42/100] Downloading 804808... ✅ Uploaded to S3
#   [43/100] Downloading 792176... ✅ Uploaded to S3
#   [44/100] Downloading 760145... ✅ Uploaded to S3
#   [45/100] Downloading 760144... ✅ Uploaded to S3
#   [46/100] Downloading 757631... ✅ Uploaded to S3
#   [47/100] Downloading 754448... ✅ Uploaded to S3
#   [48/100] Downloading 747012... ✅ Uploaded to S3
#   [49/100] Downloading 734887... ✅ Uploaded to S3
#   [50/100] Downloading 721248... ✅ Uploaded to S3
#   [51/100] Downloading 721247... ✅ Uploaded to S3
#   [52/100] Downloading 712978... ✅ Uploaded to S3
#   [53/100] Downloading 712977... ✅ Uploaded to S3
#   [54/100] Downloading 711502... ✅ Uploaded to S3
#   [55/100] Downloading 696752... ✅ Uploaded to S3
#   [56/100] Downloading 696440... ✅ Uploaded to S3
#   [57/100] Downloading 696438... ✅ Uploaded to S3
#   [58/100] Downloading 694236... ✅ Uploaded to S3
#   [59/100] Downloading 691957... ✅ Uploaded to S3
#   [60/100] Downloading 691163... ✅ Uploaded to S3
#   [61/100] Downloading 691162... ✅ Uploaded to S3
#   [62/100] Downloading 691161... ✅ Uploaded to S3
#   [63/100] Downloading 691160... ✅ Uploaded to S3
#   [64/100] Downloading 691159... ✅ Uploaded to S3
#   [65/100] Downloading 691158... ✅ Uploaded to S3
#   [66/100] Downloading 640351... ✅ Uploaded to S3
#   [67/100] Downloading 640349... ✅ Uploaded to S3
#   [68/100] Downloading 638324... ✅ Uploaded to S3
#   [69/100] Downloading 638323... ✅ Uploaded to S3
#   [70/100] Downloading 638296... ✅ Uploaded to S3
#   [71/100] Downloading 636535... ✅ Uploaded to S3
#   [72/100] Downloading 632164... ✅ Uploaded to S3
#   [73/100] Downloading 629110... ✅ Uploaded to S3
#   [74/100] Downloading 622245... ✅ Uploaded to S3
#   [75/100] Downloading 621792... ✅ Uploaded to S3
#   [76/100] Downloading 615045... ✅ Uploaded to S3
#   [77/100] Downloading 605642... ✅ Uploaded to S3
#   [78/100] Downloading 600535... ✅ Uploaded to S3
#   [79/100] Downloading 600532... ✅ Uploaded to S3
#   [80/100] Downloading 592263... ✅ Uploaded to S3
#   [81/100] Downloading 590983... ✅ Uploaded to S3
#   [82/100] Downloading 589307... ✅ Uploaded to S3
#   [83/100] Downloading 587488... ✅ Uploaded to S3
#   [84/100] Downloading 587334... ✅ Uploaded to S3
#   [85/100] Downloading 586549... ✅ Uploaded to S3
#   [86/100] Downloading 580991... ✅ Uploaded to S3
#   [87/100] Downloading 573211... ✅ Uploaded to S3
#   [88/100] Downloading 572588... ✅ Uploaded to S3
#   [89/100] Downloading 571792... ✅ Uploaded to S3
#   [90/100] Downloading 570570... ✅ Uploaded to S3
#   [91/100] Downloading 570216... ✅ Uploaded to S3
#   [92/100] Downloading 564002... ✅ Uploaded to S3
#   [93/100] Downloading 562454... ✅ Uploaded to S3
#   [94/100] Downloading 559474... ✅ Uploaded to S3
#   [95/100] Downloading 558249... ✅ Uploaded to S3
#   [96/100] Downloading 549777... ✅ Uploaded to S3
#   [97/100] Downloading 549775... ✅ Uploaded to S3
#   [98/100] Downloading 530848... ✅ Uploaded to S3
#   [99/100] Downloading 521284... ✅ Uploaded to S3
#   [100/100] Downloading 511960... ✅ Uploaded to S3
#
# Summary for Blue Jay:
#   ✅ Successful: 100
#   ❌ Failed: 0
#   📊 Total metadata entries: 100
#
# ============================================================
# Processing: American Robin (Turdus migratorius)
# ============================================================
# Querying Xeno-canto API...
# Found 100 recordings
#   [1/100] Downloading 1068477... ✅ Uploaded to S3
#   [2/100] Downloading 1049493... ✅ Uploaded to S3
#   [3/100] Downloading 1047670... ✅ Uploaded to S3
#   [4/100] Downloading 1046358... ✅ Uploaded to S3
#   [5/100] Downloading 1045448... ✅ Uploaded to S3
#   [6/100] Downloading 1023056... ✅ Uploaded to S3
#   [7/100] Downloading 1023050... ✅ Uploaded to S3
#   [8/100] Downloading 1013854... ✅ Uploaded to S3
#   [9/100] Downloading 1012677... ✅ Uploaded to S3
#   [10/100] Downloading 1012675... ✅ Uploaded to S3
#   [11/100] Downloading 1010651... ✅ Uploaded to S3
#   [12/100] Downloading 1005778... ✅ Uploaded to S3
#   [13/100] Downloading 999808... ✅ Uploaded to S3
#   [14/100] Downloading 999643... ✅ Uploaded to S3
#   [15/100] Downloading 999642... ✅ Uploaded to S3
#   [16/100] Downloading 999597... ✅ Uploaded to S3
#   [17/100] Downloading 959619... ✅ Uploaded to S3
#   [18/100] Downloading 954703... ✅ Uploaded to S3
#   [19/100] Downloading 938991... ✅ Uploaded to S3
#   [20/100] Downloading 914376... ✅ Uploaded to S3
#   [21/100] Downloading 914374... ✅ Uploaded to S3
#   [22/100] Downloading 892933... ✅ Uploaded to S3
#   [23/100] Downloading 880805... ✅ Uploaded to S3
#   [24/100] Downloading 880802... ✅ Uploaded to S3
#   [25/100] Downloading 872369... ✅ Uploaded to S3
#   [26/100] Downloading 860362... ✅ Uploaded to S3
#   [27/100] Downloading 825256... ✅ Uploaded to S3
#   [28/100] Downloading 825254... ✅ Uploaded to S3
#   [29/100] Downloading 803375... ✅ Uploaded to S3
#   [30/100] Downloading 789575... ✅ Uploaded to S3
#   [31/100] Downloading 779498... ✅ Uploaded to S3
#   [32/100] Downloading 779497... ✅ Uploaded to S3
#   [33/100] Downloading 774170... ✅ Uploaded to S3
#   [34/100] Downloading 774161... ✅ Uploaded to S3
#   [35/100] Downloading 772840... ✅ Uploaded to S3
#   [36/100] Downloading 771921... ✅ Uploaded to S3
#   [37/100] Downloading 771920... ✅ Uploaded to S3
#   [38/100] Downloading 752952... ✅ Uploaded to S3
#   [39/100] Downloading 749773... ✅ Uploaded to S3
#   [40/100] Downloading 744618... ✅ Uploaded to S3
#   [41/100] Downloading 744610... ✅ Uploaded to S3
#   [42/100] Downloading 744275... ✅ Uploaded to S3
#   [43/100] Downloading 742848... ✅ Uploaded to S3
#   [44/100] Downloading 736763... ✅ Uploaded to S3
#   [45/100] Downloading 734182... ✅ Uploaded to S3
#   [46/100] Downloading 734125... ✅ Uploaded to S3
#   [47/100] Downloading 729934... ✅ Uploaded to S3
#   [48/100] Downloading 729933... ✅ Uploaded to S3
#   [49/100] Downloading 728269... ✅ Uploaded to S3
#   [50/100] Downloading 723888... ✅ Uploaded to S3
#   [51/100] Downloading 722625... ✅ Uploaded to S3
#   [52/100] Downloading 720932... ✅ Uploaded to S3
#   [53/100] Downloading 716282... ✅ Uploaded to S3
#   [54/100] Downloading 713003... ✅ Uploaded to S3
#   [55/100] Downloading 711105... ✅ Uploaded to S3
#   [56/100] Downloading 710116... ✅ Uploaded to S3
#   [57/100] Downloading 698509... ✅ Uploaded to S3
#   [58/100] Downloading 690092... ✅ Uploaded to S3
#   [59/100] Downloading 686190... ✅ Uploaded to S3
#   [60/100] Downloading 666135... ✅ Uploaded to S3
#   [61/100] Downloading 663098... ✅ Uploaded to S3
#   [62/100] Downloading 663094... ✅ Uploaded to S3
#   [63/100] Downloading 663093... ✅ Uploaded to S3
#   [64/100] Downloading 660898... ✅ Uploaded to S3
#   [65/100] Downloading 656426... ✅ Uploaded to S3
#   [66/100] Downloading 651831... ✅ Uploaded to S3
#   [67/100] Downloading 649580... ✅ Uploaded to S3
#   [68/100] Downloading 649134... ✅ Uploaded to S3
#   [69/100] Downloading 647155... ✅ Uploaded to S3
#   [70/100] Downloading 647154... ✅ Uploaded to S3
#   [71/100] Downloading 645161... ✅ Uploaded to S3
#   [72/100] Downloading 641669... ✅ Uploaded to S3
#   [73/100] Downloading 641578... ✅ Uploaded to S3
#   [74/100] Downloading 640975... ✅ Uploaded to S3
#   [75/100] Downloading 639265... ✅ Uploaded to S3
#   [76/100] Downloading 638326... ✅ Uploaded to S3
#   [77/100] Downloading 636519... ✅ Uploaded to S3
#   [78/100] Downloading 636181... ✅ Uploaded to S3
#   [79/100] Downloading 635395... ✅ Uploaded to S3
#   [80/100] Downloading 624425... ✅ Uploaded to S3
#   [81/100] Downloading 610952... ✅ Uploaded to S3
#   [82/100] Downloading 610883... ✅ Uploaded to S3
#   [83/100] Downloading 599316... ✅ Uploaded to S3
#   [84/100] Downloading 574494... ✅ Uploaded to S3
#   [85/100] Downloading 574489... ✅ Uploaded to S3
#   [86/100] Downloading 574487... ✅ Uploaded to S3
#   [87/100] Downloading 574486... ✅ Uploaded to S3
#   [88/100] Downloading 574484... ✅ Uploaded to S3
#   [89/100] Downloading 574483... ✅ Uploaded to S3
#   [90/100] Downloading 574482... ✅ Uploaded to S3
#   [91/100] Downloading 574476... ✅ Uploaded to S3
#   [92/100] Downloading 574473... ✅ Uploaded to S3
#   [93/100] Downloading 574471... ✅ Uploaded to S3
#   [94/100] Downloading 574469... ✅ Uploaded to S3
#   [95/100] Downloading 574466... ✅ Uploaded to S3
#   [96/100] Downloading 574171... ✅ Uploaded to S3
#   [97/100] Downloading 573924... ✅ Uploaded to S3
#   [98/100] Downloading 572715... ✅ Uploaded to S3
#   [99/100] Downloading 572223... ✅ Uploaded to S3
#   [100/100] Downloading 572222... ✅ Uploaded to S3
#
# Summary for American Robin:
#   ✅ Successful: 100
#   ❌ Failed: 0
#   📊 Total metadata entries: 100
#
# ============================================================
# Processing: Mourning Dove (Zenaida macroura)
# ============================================================
# Querying Xeno-canto API...
# Found 54 recordings
#   [1/54] Downloading 1013493... ✅ Uploaded to S3
#   [2/54] Downloading 1013012... ✅ Uploaded to S3
#   [3/54] Downloading 995960... ✅ Uploaded to S3
#   [4/54] Downloading 995959... ✅ Uploaded to S3
#   [5/54] Downloading 995957... ✅ Uploaded to S3
#   [6/54] Downloading 940517... ✅ Uploaded to S3
#   [7/54] Downloading 807126... ✅ Uploaded to S3
#   [8/54] Downloading 767710... ✅ Uploaded to S3
#   [9/54] Downloading 696289... ✅ Uploaded to S3
#   [10/54] Downloading 691623... ✅ Uploaded to S3
#   [11/54] Downloading 661720... ✅ Uploaded to S3
#   [12/54] Downloading 638304... ✅ Uploaded to S3
#   [13/54] Downloading 636552... ✅ Uploaded to S3
#   [14/54] Downloading 621378... ✅ Uploaded to S3
#   [15/54] Downloading 621377... ✅ Uploaded to S3
#   [16/54] Downloading 621374... ✅ Uploaded to S3
#   [17/54] Downloading 613539... ✅ Uploaded to S3
#   [18/54] Downloading 583581... ✅ Uploaded to S3
#   [19/54] Downloading 583580... ✅ Uploaded to S3
#   [20/54] Downloading 583577... ✅ Uploaded to S3
#   [21/54] Downloading 583575... ✅ Uploaded to S3
#   [22/54] Downloading 583574... ✅ Uploaded to S3
#   [23/54] Downloading 580701... ✅ Uploaded to S3
#   [24/54] Downloading 495471... ✅ Uploaded to S3
#   [25/54] Downloading 493300... ✅ Uploaded to S3
#   [26/54] Downloading 476933... ✅ Uploaded to S3
#   [27/54] Downloading 459335... ✅ Uploaded to S3
#   [28/54] Downloading 451819... ✅ Uploaded to S3
#   [29/54] Downloading 430095... ✅ Uploaded to S3
#   [30/54] Downloading 407859... ✅ Uploaded to S3
#   [31/54] Downloading 382741... ✅ Uploaded to S3
#   [32/54] Downloading 381111... ✅ Uploaded to S3
#   [33/54] Downloading 349471... ✅ Uploaded to S3
#   [34/54] Downloading 268216... ✅ Uploaded to S3
#   [35/54] Downloading 268211... ✅ Uploaded to S3
#   [36/54] Downloading 268209... ✅ Uploaded to S3
#   [37/54] Downloading 268208... ✅ Uploaded to S3
#   [38/54] Downloading 268207... ✅ Uploaded to S3
#   [39/54] Downloading 268206... ✅ Uploaded to S3
#   [40/54] Downloading 179721... ✅ Uploaded to S3
#   [41/54] Downloading 153654... ✅ Uploaded to S3
#   [42/54] Downloading 153653... ✅ Uploaded to S3
#   [43/54] Downloading 153652... ✅ Uploaded to S3
#   [44/54] Downloading 153651... ✅ Uploaded to S3
#   [45/54] Downloading 153648... ✅ Uploaded to S3
#   [46/54] Downloading 153645... ✅ Uploaded to S3
#   [47/54] Downloading 153639... ✅ Uploaded to S3
#   [48/54] Downloading 131448... ✅ Uploaded to S3
#   [49/54] Downloading 109033... ✅ Uploaded to S3
#   [50/54] Downloading 46669... ✅ Uploaded to S3
#   [51/54] Downloading 35102... ✅ Uploaded to S3
#   [52/54] Downloading 35100... ✅ Uploaded to S3
#   [53/54] Downloading 14872... ✅ Uploaded to S3
#   [54/54] Downloading 14871... ✅ Uploaded to S3
#
# Summary for Mourning Dove:
#   ✅ Successful: 54
#   ❌ Failed: 0
#   📊 Total metadata entries: 54
#
# ============================================================
# Processing: Tufted Titmouse (Baeolophus bicolor)
# ============================================================
# Querying Xeno-canto API...
# Found 100 recordings
#   [1/100] Downloading 1035994... ✅ Uploaded to S3
#   [2/100] Downloading 1027848... ✅ Uploaded to S3
#   [3/100] Downloading 1014938... ✅ Uploaded to S3
#   [4/100] Downloading 1014937... ✅ Uploaded to S3
#   [5/100] Downloading 1010613... ✅ Uploaded to S3
#   [6/100] Downloading 951797... ✅ Uploaded to S3
#   [7/100] Downloading 951796... ✅ Uploaded to S3
#   [8/100] Downloading 941253... ✅ Uploaded to S3
#   [9/100] Downloading 900409... ✅ Uploaded to S3
#   [10/100] Downloading 899085... ✅ Uploaded to S3
#   [11/100] Downloading 895984... ✅ Uploaded to S3
#   [12/100] Downloading 895279... ✅ Uploaded to S3
#   [13/100] Downloading 884288... ✅ Uploaded to S3
#   [14/100] Downloading 879235... ✅ Uploaded to S3
#   [15/100] Downloading 879234... ✅ Uploaded to S3
#   [16/100] Downloading 879233... ✅ Uploaded to S3
#   [17/100] Downloading 879232... ✅ Uploaded to S3
#   [18/100] Downloading 879231... ✅ Uploaded to S3
#   [19/100] Downloading 875276... ✅ Uploaded to S3
#   [20/100] Downloading 861595... ✅ Uploaded to S3
#   [21/100] Downloading 827249... ✅ Uploaded to S3
#   [22/100] Downloading 827248... ✅ Uploaded to S3
#   [23/100] Downloading 827247... ✅ Uploaded to S3
#   [24/100] Downloading 827245... ✅ Uploaded to S3
#   [25/100] Downloading 827244... ✅ Uploaded to S3
#   [26/100] Downloading 827241... ✅ Uploaded to S3
#   [27/100] Downloading 827240... ✅ Uploaded to S3
#   [28/100] Downloading 814179... ✅ Uploaded to S3
#   [29/100] Downloading 814177... ✅ Uploaded to S3
#   [30/100] Downloading 793408... ✅ Uploaded to S3
#   [31/100] Downloading 785277... ✅ Uploaded to S3
#   [32/100] Downloading 781968... ✅ Uploaded to S3
#   [33/100] Downloading 713584... ✅ Uploaded to S3
#   [34/100] Downloading 713261... ✅ Uploaded to S3
#   [35/100] Downloading 713258... ✅ Uploaded to S3
#   [36/100] Downloading 712980... ✅ Uploaded to S3
#   [37/100] Downloading 706242... ✅ Uploaded to S3
#   [38/100] Downloading 703749... ✅ Uploaded to S3
#   [39/100] Downloading 701551... ✅ Uploaded to S3
#   [40/100] Downloading 692191... ✅ Uploaded to S3
#   [41/100] Downloading 649331... ✅ Uploaded to S3
#   [42/100] Downloading 627685... ✅ Uploaded to S3
#   [43/100] Downloading 624947... ✅ Uploaded to S3
#   [44/100] Downloading 623003... ✅ Uploaded to S3
#   [45/100] Downloading 600069... ✅ Uploaded to S3
#   [46/100] Downloading 591473... ✅ Uploaded to S3
#   [47/100] Downloading 590611... ✅ Uploaded to S3
#   [48/100] Downloading 572390... ✅ Uploaded to S3
#   [49/100] Downloading 572375... ✅ Uploaded to S3
#   [50/100] Downloading 569728... ✅ Uploaded to S3
#   [51/100] Downloading 568906... ✅ Uploaded to S3
#   [52/100] Downloading 562016... ✅ Uploaded to S3
#   [53/100] Downloading 556166... ✅ Uploaded to S3
#   [54/100] Downloading 544303... ✅ Uploaded to S3
#   [55/100] Downloading 529792... ✅ Uploaded to S3
#   [56/100] Downloading 522855... ✅ Uploaded to S3
#   [57/100] Downloading 501232... ✅ Uploaded to S3
#   [58/100] Downloading 501231... ✅ Uploaded to S3
#   [59/100] Downloading 499563... ✅ Uploaded to S3
#   [60/100] Downloading 479486... ✅ Uploaded to S3
#   [61/100] Downloading 469655... ✅ Uploaded to S3
#   [62/100] Downloading 469582... ✅ Uploaded to S3
#   [63/100] Downloading 467635... ✅ Uploaded to S3
#   [64/100] Downloading 465256... ✅ Uploaded to S3
#   [65/100] Downloading 465058... ✅ Uploaded to S3
#   [66/100] Downloading 463360... ✅ Uploaded to S3
#   [67/100] Downloading 446662... ✅ Uploaded to S3
#   [68/100] Downloading 428278... ✅ Uploaded to S3
#   [69/100] Downloading 422042... ✅ Uploaded to S3
#   [70/100] Downloading 385825... ✅ Uploaded to S3
#   [71/100] Downloading 375008... ✅ Uploaded to S3
#   [72/100] Downloading 363065... ✅ Uploaded to S3
#   [73/100] Downloading 348110... ✅ Uploaded to S3
#   [74/100] Downloading 333285... ✅ Uploaded to S3
#   [75/100] Downloading 322769... ✅ Uploaded to S3
#   [76/100] Downloading 318897... ✅ Uploaded to S3
#   [77/100] Downloading 316285... ✅ Uploaded to S3
#   [78/100] Downloading 313159... ✅ Uploaded to S3
#   [79/100] Downloading 311712... ✅ Uploaded to S3
#   [80/100] Downloading 310835... ✅ Uploaded to S3
#   [81/100] Downloading 309396... ✅ Uploaded to S3
#   [82/100] Downloading 308401... ✅ Uploaded to S3
#   [83/100] Downloading 306851... ✅ Uploaded to S3
#   [84/100] Downloading 305136... ✅ Uploaded to S3
#   [85/100] Downloading 305015... ✅ Uploaded to S3
#   [86/100] Downloading 299474... ✅ Uploaded to S3
#   [87/100] Downloading 290151... ✅ Uploaded to S3
#   [88/100] Downloading 236017... ✅ Uploaded to S3
#   [89/100] Downloading 196755... ✅ Uploaded to S3
#   [90/100] Downloading 174892... ✅ Uploaded to S3
#   [91/100] Downloading 174397... ✅ Uploaded to S3
#   [92/100] Downloading 172590... ✅ Uploaded to S3
#   [93/100] Downloading 168057... ✅ Uploaded to S3
#   [94/100] Downloading 164758... ✅ Uploaded to S3
#   [95/100] Downloading 145941... ✅ Uploaded to S3
#   [96/100] Downloading 145938... ✅ Uploaded to S3
#   [97/100] Downloading 101646... ✅ Uploaded to S3
#   [98/100] Downloading 97374... ✅ Uploaded to S3
#   [99/100] Downloading 60068... ✅ Uploaded to S3
#   [100/100] Downloading 59158... ✅ Uploaded to S3
#
# Summary for Tufted Titmouse:
#   ✅ Successful: 100
#   ❌ Failed: 0
#   📊 Total metadata entries: 100
#
# ============================================================
# Processing: Carolina Chickadee (Poecile carolinensis)
# ============================================================
# Querying Xeno-canto API...
# Found 78 recordings
#   [1/78] Downloading 1010608... ✅ Uploaded to S3
#   [2/78] Downloading 959878... ✅ Uploaded to S3
#   [3/78] Downloading 955910... ✅ Uploaded to S3
#   [4/78] Downloading 955593... ✅ Uploaded to S3
#   [5/78] Downloading 938770... ✅ Uploaded to S3
#   [6/78] Downloading 933606... ✅ Uploaded to S3
#   [7/78] Downloading 933605... ✅ Uploaded to S3
#   [8/78] Downloading 933604... ✅ Uploaded to S3
#   [9/78] Downloading 884282... ✅ Uploaded to S3
#   [10/78] Downloading 877923... ✅ Uploaded to S3
#   [11/78] Downloading 877922... ✅ Uploaded to S3
#   [12/78] Downloading 877921... ✅ Uploaded to S3
#   [13/78] Downloading 877920... ✅ Uploaded to S3
#   [14/78] Downloading 877919... ✅ Uploaded to S3
#   [15/78] Downloading 877918... ✅ Uploaded to S3
#   [16/78] Downloading 877917... ✅ Uploaded to S3
#   [17/78] Downloading 877868... ✅ Uploaded to S3
#   [18/78] Downloading 871064... ✅ Uploaded to S3
#   [19/78] Downloading 871058... ✅ Uploaded to S3
#   [20/78] Downloading 870687... ✅ Uploaded to S3
#   [21/78] Downloading 870686... ✅ Uploaded to S3
#   [22/78] Downloading 862284... ✅ Uploaded to S3
#   [23/78] Downloading 861741... ✅ Uploaded to S3
#   [24/78] Downloading 814918... ✅ Uploaded to S3
#   [25/78] Downloading 814916... ✅ Uploaded to S3
#   [26/78] Downloading 807462... ✅ Uploaded to S3
#   [27/78] Downloading 796340... ✅ Uploaded to S3
#   [28/78] Downloading 734763... ✅ Uploaded to S3
#   [29/78] Downloading 717444... ✅ Uploaded to S3
#   [30/78] Downloading 616706... ✅ Uploaded to S3
#   [31/78] Downloading 606052... ✅ Uploaded to S3
#   [32/78] Downloading 572217... ✅ Uploaded to S3
#   [33/78] Downloading 572215... ✅ Uploaded to S3
#   [34/78] Downloading 571268... ✅ Uploaded to S3
#   [35/78] Downloading 566447... ✅ Uploaded to S3
#   [36/78] Downloading 483022... ✅ Uploaded to S3
#   [37/78] Downloading 466694... ✅ Uploaded to S3
#   [38/78] Downloading 452616... ✅ Uploaded to S3
#   [39/78] Downloading 391442... ✅ Uploaded to S3
#   [40/78] Downloading 391432... ✅ Uploaded to S3
#   [41/78] Downloading 391431... ✅ Uploaded to S3
#   [42/78] Downloading 366600... ✅ Uploaded to S3
#   [43/78] Downloading 364473... ✅ Uploaded to S3
#   [44/78] Downloading 362250... ✅ Uploaded to S3
#   [45/78] Downloading 360934... ✅ Uploaded to S3
#   [46/78] Downloading 339932... ✅ Uploaded to S3
#   [47/78] Downloading 310196... ✅ Uploaded to S3
#   [48/78] Downloading 309927... ✅ Uploaded to S3
#   [49/78] Downloading 309925... ✅ Uploaded to S3
#   [50/78] Downloading 309487... ✅ Uploaded to S3
#   [51/78] Downloading 232860... ✅ Uploaded to S3
#   [52/78] Downloading 227271... ✅ Uploaded to S3
#   [53/78] Downloading 227270... ✅ Uploaded to S3
#   [54/78] Downloading 172591... ✅ Uploaded to S3
#   [55/78] Downloading 167824... ✅ Uploaded to S3
#   [56/78] Downloading 154971... ✅ Uploaded to S3
#   [57/78] Downloading 138604... ✅ Uploaded to S3
#   [58/78] Downloading 123410... ✅ Uploaded to S3
#   [59/78] Downloading 123408... ✅ Uploaded to S3
#   [60/78] Downloading 121934... ✅ Uploaded to S3
#   [61/78] Downloading 121933... ✅ Uploaded to S3
#   [62/78] Downloading 121932... ✅ Uploaded to S3
#   [63/78] Downloading 121930... ✅ Uploaded to S3
#   [64/78] Downloading 121929... ✅ Uploaded to S3
#   [65/78] Downloading 112633... ✅ Uploaded to S3
#   [66/78] Downloading 112510... ✅ Uploaded to S3
#   [67/78] Downloading 111140... ✅ Uploaded to S3
#   [68/78] Downloading 70980... ✅ Uploaded to S3
#   [69/78] Downloading 57446... ✅ Uploaded to S3
#   [70/78] Downloading 57445... ✅ Uploaded to S3
#   [71/78] Downloading 57321... ✅ Uploaded to S3
#   [72/78] Downloading 34951... ✅ Uploaded to S3
#   [73/78] Downloading 34950... ✅ Uploaded to S3
#   [74/78] Downloading 33598... ✅ Uploaded to S3
#   [75/78] Downloading 18446... ✅ Uploaded to S3
#   [76/78] Downloading 18445... ✅ Uploaded to S3
#   [77/78] Downloading 15190... ✅ Uploaded to S3
#   [78/78] Downloading 15189... ✅ Uploaded to S3
#
# Summary for Carolina Chickadee:
#   ✅ Successful: 78
#   ❌ Failed: 0
#   📊 Total metadata entries: 78
#
# ============================================================
# Processing: Eastern Bluebird (Sialia sialis)
# ============================================================
# Querying Xeno-canto API...
# Found 61 recordings
#   [1/61] Downloading 1059664... ✅ Uploaded to S3
#   [2/61] Downloading 1045482... ✅ Uploaded to S3
#   [3/61] Downloading 1027243... ✅ Uploaded to S3
#   [4/61] Downloading 1014698... ✅ Uploaded to S3
#   [5/61] Downloading 1014697... ✅ Uploaded to S3
#   [6/61] Downloading 1014696... ✅ Uploaded to S3
#   [7/61] Downloading 890154... ✅ Uploaded to S3
#   [8/61] Downloading 890151... ✅ Uploaded to S3
#   [9/61] Downloading 890150... ✅ Uploaded to S3
#   [10/61] Downloading 890146... ✅ Uploaded to S3
#   [11/61] Downloading 844282... ✅ Uploaded to S3
#   [12/61] Downloading 824503... ✅ Uploaded to S3
#   [13/61] Downloading 712412... ✅ Uploaded to S3
#   [14/61] Downloading 638302... ✅ Uploaded to S3
#   [15/61] Downloading 626711... ✅ Uploaded to S3
#   [16/61] Downloading 608740... ✅ Uploaded to S3
#   [17/61] Downloading 604632... ✅ Uploaded to S3
#   [18/61] Downloading 601013... ✅ Uploaded to S3
#   [19/61] Downloading 601011... ✅ Uploaded to S3
#   [20/61] Downloading 601010... ✅ Uploaded to S3
#   [21/61] Downloading 599325... ✅ Uploaded to S3
#   [22/61] Downloading 589468... ✅ Uploaded to S3
#   [23/61] Downloading 570650... ✅ Uploaded to S3
#   [24/61] Downloading 570566... ✅ Uploaded to S3
#   [25/61] Downloading 570310... ✅ Uploaded to S3
#   [26/61] Downloading 502284... ✅ Uploaded to S3
#   [27/61] Downloading 502283... ✅ Uploaded to S3
#   [28/61] Downloading 502282... ✅ Uploaded to S3
#   [29/61] Downloading 498959... ✅ Uploaded to S3
#   [30/61] Downloading 481975... ✅ Uploaded to S3
#   [31/61] Downloading 481623... ✅ Uploaded to S3
#   [32/61] Downloading 452141... ✅ Uploaded to S3
#   [33/61] Downloading 452139... ✅ Uploaded to S3
#   [34/61] Downloading 439868... ✅ Uploaded to S3
#   [35/61] Downloading 439864... ✅ Uploaded to S3
#   [36/61] Downloading 420915... ✅ Uploaded to S3
#   [37/61] Downloading 409000... ✅ Uploaded to S3
#   [38/61] Downloading 408999... ✅ Uploaded to S3
#   [39/61] Downloading 408998... ✅ Uploaded to S3
#   [40/61] Downloading 408997... ✅ Uploaded to S3
#   [41/61] Downloading 408996... ✅ Uploaded to S3
#   [42/61] Downloading 408995... ✅ Uploaded to S3
#   [43/61] Downloading 378953... ✅ Uploaded to S3
#   [44/61] Downloading 376223... ✅ Uploaded to S3
#   [45/61] Downloading 367784... ✅ Uploaded to S3
#   [46/61] Downloading 337449...   Retry 1/3 after 1s...
# ✅ Uploaded to S3
#   [47/61] Downloading 337447... ✅ Uploaded to S3
#   [48/61] Downloading 301392... ✅ Uploaded to S3
#   [49/61] Downloading 180252... ✅ Uploaded to S3
#   [50/61] Downloading 180249... ✅ Uploaded to S3
#   [51/61] Downloading 179669... ✅ Uploaded to S3
#   [52/61] Downloading 171698... ✅ Uploaded to S3
#   [53/61] Downloading 167838... ✅ Uploaded to S3
#   [54/61] Downloading 150395... ✅ Uploaded to S3
#   [55/61] Downloading 139431... ✅ Uploaded to S3
#   [56/61] Downloading 139430... ✅ Uploaded to S3
#   [57/61] Downloading 137538... ✅ Uploaded to S3
#   [58/61] Downloading 70120... ✅ Uploaded to S3
#   [59/61] Downloading 18392... ✅ Uploaded to S3
#   [60/61] Downloading 18391... ✅ Uploaded to S3
#   [61/61] Downloading 1374... ✅ Uploaded to S3
#
# Summary for Eastern Bluebird:
#   ✅ Successful: 61
#   ❌ Failed: 0
#   📊 Total metadata entries: 61
#
# ============================================================
# Pipeline Complete!
# ============================================================
# Total recordings processed: 692
# Total errors: 0

# %%
# Generate and upload metadata files

if all_metadata:
    # Create DataFrame
    df = pd.DataFrame(all_metadata)
    
    # Save to temporary files
    temp_dir = Path("/tmp/bird_metadata")
    temp_dir.mkdir(exist_ok=True)
    
    csv_path = temp_dir / "recordings_metadata.csv"
    json_path = temp_dir / "recordings_metadata.json"
    
    # Save CSV
    df.to_csv(csv_path, index=False)
    print(f"✅ Created CSV metadata: {csv_path}")
    
    # Save JSON
    df.to_json(json_path, orient='records', indent=2)
    print(f"✅ Created JSON metadata: {json_path}")
    
    # Upload to S3
    csv_s3_uri = s3_manager.upload_metadata_file(str(csv_path), "recordings_metadata")
    json_s3_uri = s3_manager.upload_metadata_file(str(json_path), "recordings_metadata")
    
    if csv_s3_uri:
        print(f"✅ Uploaded CSV to S3: {csv_s3_uri}")
    if json_s3_uri:
        print(f"✅ Uploaded JSON to S3: {json_s3_uri}")
    
    # Display summary statistics
    print(f"\n{'='*60}")
    print(f"Dataset Summary")
    print(f"{'='*60}")
    print(f"Total recordings: {len(df)}")
    print(f"\nRecordings per species:")
    species_counts = df['species_common_name'].value_counts()
    for species, count in species_counts.items():
        print(f"  {species}: {count}")
    
    print(f"\nQuality distribution:")
    quality_counts = df['recording_quality'].value_counts()
    for quality, count in quality_counts.items():
        print(f"  Quality {quality}: {count}")
    
    print(f"\nTotal duration: {df['duration_seconds'].sum() / 60:.1f} minutes")
    print(f"Average duration: {df['duration_seconds'].mean():.1f} seconds")
    
    # Display first few rows
    print(f"\nSample metadata:")
    print(df.head().to_string())
else:
    print("⚠️ No metadata to process")
# Out:
# ✅ Created CSV metadata: /tmp/bird_metadata/recordings_metadata.csv
# ✅ Created JSON metadata: /tmp/bird_metadata/recordings_metadata.json
# ✅ Uploaded CSV to S3: s3://bird-classification-data/metadata/recordings_metadata.csv
# ✅ Uploaded JSON to S3: s3://bird-classification-data/metadata/recordings_metadata.json
#
# ============================================================
# Dataset Summary
# ============================================================
# Total recordings: 692
#
# Recordings per species:
#   Northern Cardinal: 100
#   Blue Jay: 100
#   American Robin: 100
#   Tufted Titmouse: 100
#   Carolina Wren: 99
#   Carolina Chickadee: 78
#   Eastern Bluebird: 61
#   Mourning Dove: 54
#
# Quality distribution:
#   Quality A: 692
#
# Total duration: 711.0 minutes
# Average duration: 61.6 seconds
#
# Sample metadata:
#   recording_id species_common_name species_scientific_name                                                           audio_s3_uri recording_quality  duration_seconds duration_formatted                                                          location        country        date                  xeno_canto_url       genus     species                                 file_url
# 0      1070756   Northern Cardinal   Cardinalis cardinalis  s3://bird-classification-data/raw-audio/northern_cardinal/1070756.mp3                 A                29               0:29  Lorance Township (near  Marble Hill), Bollinger County, Missouri  United States  2026-01-01  https://xeno-canto.org/1070756  Cardinalis  cardinalis  https://xeno-canto.org/1070756/download
# 1      1070366   Northern Cardinal   Cardinalis cardinalis  s3://bird-classification-data/raw-audio/northern_cardinal/1070366.mp3                 A               174               2:54  Lorance Township (near  Marble Hill), Bollinger County, Missouri  United States  2026-01-02  https://xeno-canto.org/1070366  Cardinalis  cardinalis  https://xeno-canto.org/1070366/download
# 2      1027842   Northern Cardinal   Cardinalis cardinalis  s3://bird-classification-data/raw-audio/northern_cardinal/1027842.mp3                 A               135               2:15                            Jamestown, Chautauqua County, New York  United States  2025-07-08  https://xeno-canto.org/1027842  Cardinalis  cardinalis  https://xeno-canto.org/1027842/download
# 3      1012918   Northern Cardinal   Cardinalis cardinalis  s3://bird-classification-data/raw-audio/northern_cardinal/1012918.mp3                 A                66               1:06                          Marais Léon-Provancher, Portneuf, Québec         Canada  2025-05-21  https://xeno-canto.org/1012918  Cardinalis  cardinalis  https://xeno-canto.org/1012918/download
# 4      1012917   Northern Cardinal   Cardinalis cardinalis  s3://bird-classification-data/raw-audio/northern_cardinal/1012917.mp3                 A                 6               0:06                          Marais Léon-Provancher, Portneuf, Québec         Canada  2025-05-21  https://xeno-canto.org/1012917  Cardinalis  cardinalis  https://xeno-canto.org/1012917/download
