# %%
# Load environment variables from .env file
from dotenv import load_dotenv
load_dotenv()

# Import services and libraries
import sys
sys.path.append('..')
import pandas as pd
import json
from pathlib import Path
from typing import Dict, List, Optional
import tempfile

from services.s3_manager import S3Manager
from services.spectrogram_manager import SpectrogramManager

# Initialize managers
s3_manager = S3Manager(create_bucket_if_not_exists=False)
spectrogram_manager = SpectrogramManager()

print(f"✅ S3 Manager initialized for bucket: {s3_manager.bucket_name}")
print(f"✅ Spectrogram Manager initialized")
print(f"\nDefault spectrogram parameters:")
params = spectrogram_manager.get_default_params()
for key, value in params.items():
    print(f"  {key}: {value}")
# Out:
# /var/folders/wc/js21wthx2f33wln3fbvy9shm0000gn/T/ipykernel_27408/2461820325.py:8: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Matplotlib is building the font cache; this may take a moment.
# ✅ S3 Manager initialized for bucket: bird-classification-data
# ✅ Spectrogram Manager initialized
#
# Default spectrogram parameters:
#   n_fft: 2048
#   hop_length: 512
#   n_mels: 128
#   fmin: 0
#   fmax: 8000
#   sr: 22050
#   dpi: 100
#   figsize: (10, 4)

# %%
# Load recordings metadata from S3

# Download metadata CSV from S3
metadata_s3_key = "metadata/recordings_metadata.csv"
temp_dir = Path("/tmp/bird_metadata")
temp_dir.mkdir(exist_ok=True)
local_metadata_path = temp_dir / "recordings_metadata.csv"

print(f"Downloading metadata from S3...")
if s3_manager.download_file(metadata_s3_key, str(local_metadata_path)):
    print(f"✅ Downloaded metadata to {local_metadata_path}")
    
    # Load into DataFrame
    df_recordings = pd.read_csv(local_metadata_path)
    print(f"\n✅ Loaded {len(df_recordings)} recordings from metadata")
    print(f"\nRecordings per species:")
    species_counts = df_recordings['species_common_name'].value_counts()
    for species, count in species_counts.items():
        print(f"  {species}: {count}")
else:
    print("❌ Failed to download metadata from S3")
    df_recordings = pd.DataFrame()
# Out:
# Downloading metadata from S3...
# ✅ Downloaded metadata to /tmp/bird_metadata/recordings_metadata.csv
#
# ✅ Loaded 692 recordings from metadata
#
# Recordings per species:
#   Northern Cardinal: 100
#   Blue Jay: 100
#   American Robin: 100
#   Tufted Titmouse: 100
#   Carolina Wren: 99
#   Carolina Chickadee: 78
#   Eastern Bluebird: 61
#   Mourning Dove: 54

# %%
# Helper function to process a single recording

def process_recording_for_spectrogram(
    recording_row: pd.Series,
    skip_existing: bool = True,
    temp_dir: str = "/tmp/spectrogram_processing"
) -> Optional[Dict]:
    """
    Process a single recording: download audio, generate spectrogram, upload to S3.
    
    Args:
        recording_row: Pandas Series with recording metadata
        skip_existing: If True, skip if spectrogram already exists
        temp_dir: Temporary directory for processing
    
    Returns:
        Dictionary with spectrogram metadata, or None if processing failed
    """
    recording_id = str(recording_row['recording_id'])
    species_common_name = recording_row['species_common_name']
    audio_s3_uri = recording_row['audio_s3_uri']
    
    # Check if spectrogram already exists
    if skip_existing and s3_manager.spectrogram_exists(species_common_name, recording_id):
        return None  # Already processed
    
    # Extract S3 key from URI (format: s3://bucket/key)
    if not audio_s3_uri.startswith('s3://'):
        print(f"  ⚠️ Invalid S3 URI for {recording_id}: {audio_s3_uri}")
        return None
    
    s3_key = audio_s3_uri.replace(f"s3://{s3_manager.bucket_name}/", "")
    
    # Create temp directories
    temp_path = Path(temp_dir)
    temp_path.mkdir(parents=True, exist_ok=True)
    audio_temp = temp_path / f"{recording_id}_audio.mp3"
    spectrogram_temp = temp_path / f"{recording_id}_spectrogram.png"
    
    try:
        # Download audio from S3
        if not s3_manager.download_file(s3_key, str(audio_temp)):
            print(f"  ❌ Failed to download audio for {recording_id}")
            return None
        
        # Generate spectrogram
        spectrogram_metadata = spectrogram_manager.generate_mel_spectrogram(
            str(audio_temp),
            str(spectrogram_temp)
        )
        
        # Upload spectrogram to S3
        spectrogram_s3_uri = s3_manager.upload_spectrogram_file(
            str(spectrogram_temp),
            species_common_name,
            recording_id
        )
        
        if not spectrogram_s3_uri:
            print(f"  ❌ Failed to upload spectrogram for {recording_id}")
            return None
        
        # Clean up local files
        audio_temp.unlink(missing_ok=True)
        spectrogram_temp.unlink(missing_ok=True)
        
        # Build metadata dictionary
        return {
            'recording_id': recording_id,
            'spectrogram_s3_uri': spectrogram_s3_uri,
            'audio_s3_uri': audio_s3_uri,
            'spectrogram_params': spectrogram_metadata['spectrogram_params'],
            'image_width': spectrogram_metadata['image_width'],
            'image_height': spectrogram_metadata['image_height'],
            'sample_rate': spectrogram_metadata['sample_rate'],
            'duration_seconds': spectrogram_metadata['duration_seconds'],
            'species_common_name': species_common_name,
            'species_scientific_name': recording_row['species_scientific_name']
        }
        
    except Exception as e:
        print(f"  ❌ Error processing {recording_id}: {e}")
        # Clean up on error
        audio_temp.unlink(missing_ok=True)
        spectrogram_temp.unlink(missing_ok=True)
        return None

print("✅ Helper function defined")
# Out:
# ✅ Helper function defined

# %%
# Process all recordings to generate spectrograms

if len(df_recordings) == 0:
    print("⚠️ No recordings to process")
else:
    all_spectrogram_metadata = []
    errors = []
    skipped = 0
    
    print(f"Starting spectrogram generation pipeline...")
    print(f"Total recordings: {len(df_recordings)}")
    print(f"Skip existing: True\n")
    
    for idx, (_, row) in enumerate(df_recordings.iterrows(), 1):
        recording_id = str(row['recording_id'])
        species = row['species_common_name']
        
        print(f"[{idx}/{len(df_recordings)}] Processing {recording_id} ({species})...", end=' ')
        
        # Check if already exists
        if s3_manager.spectrogram_exists(species, recording_id):
            print("⏭️ Already exists, skipping")
            skipped += 1
            continue
        
        result = process_recording_for_spectrogram(row, skip_existing=False)
        
        if result:
            all_spectrogram_metadata.append(result)
            print("✅ Generated and uploaded")
        else:
            errors.append(f"{recording_id} ({species})")
            print("❌ Failed")
    
    print(f"\n{'='*60}")
    print(f"Spectrogram Generation Complete!")
    print(f"{'='*60}")
    print(f"✅ Successfully processed: {len(all_spectrogram_metadata)}")
    print(f"⏭️ Skipped (already exists): {skipped}")
    print(f"❌ Failed: {len(errors)}")
    
    if errors:
        print(f"\nFailed recordings:")
        for error in errors[:10]:  # Show first 10
            print(f"  - {error}")
        if len(errors) > 10:
            print(f"  ... and {len(errors) - 10} more")
# Out:
# Starting spectrogram generation pipeline...
# Total recordings: 692
# Skip existing: True
#
# [1/692] Processing 1070756 (Northern Cardinal)... ✅ Generated and uploaded
# [2/692] Processing 1070366 (Northern Cardinal)... ✅ Generated and uploaded
# [3/692] Processing 1027842 (Northern Cardinal)... ✅ Generated and uploaded
# [4/692] Processing 1012918 (Northern Cardinal)... ✅ Generated and uploaded
# [5/692] Processing 1012917 (Northern Cardinal)... ✅ Generated and uploaded
# [6/692] Processing 1012916 (Northern Cardinal)... ✅ Generated and uploaded
# [7/692] Processing 1012495 (Northern Cardinal)... ✅ Generated and uploaded
# [8/692] Processing 1012494 (Northern Cardinal)... ✅ Generated and uploaded
# [9/692] Processing 1012493 (Northern Cardinal)... ✅ Generated and uploaded
# [10/692] Processing 1012492 (Northern Cardinal)... ✅ Generated and uploaded
# [11/692] Processing 1012491 (Northern Cardinal)... ✅ Generated and uploaded
# [12/692] Processing 1012142 (Northern Cardinal)... ✅ Generated and uploaded
# [13/692] Processing 1010649 (Northern Cardinal)... ✅ Generated and uploaded
# [14/692] Processing 1010609 (Northern Cardinal)... ✅ Generated and uploaded
# [15/692] Processing 1006772 (Northern Cardinal)... ✅ Generated and uploaded
# [16/692] Processing 1000327 (Northern Cardinal)... ✅ Generated and uploaded
# [17/692] Processing 1000248 (Northern Cardinal)... ✅ Generated and uploaded
# [18/692] Processing 995475 (Northern Cardinal)... ✅ Generated and uploaded
# [19/692] Processing 984331 (Northern Cardinal)... ✅ Generated and uploaded
# [20/692] Processing 962371 (Northern Cardinal)... ✅ Generated and uploaded
# [21/692] Processing 952632 (Northern Cardinal)... ✅ Generated and uploaded
# [22/692] Processing 941475 (Northern Cardinal)... ✅ Generated and uploaded
# [23/692] Processing 931722 (Northern Cardinal)... ✅ Generated and uploaded
# [24/692] Processing 931717 (Northern Cardinal)... ✅ Generated and uploaded
# [25/692] Processing 931709 (Northern Cardinal)... ✅ Generated and uploaded
# [26/692] Processing 931706 (Northern Cardinal)... ✅ Generated and uploaded
# [27/692] Processing 931704 (Northern Cardinal)... ✅ Generated and uploaded
# [28/692] Processing 930723 (Northern Cardinal)... ✅ Generated and uploaded
# [29/692] Processing 920145 (Northern Cardinal)... ✅ Generated and uploaded
# [30/692] Processing 920144 (Northern Cardinal)... ✅ Generated and uploaded
# [31/692] Processing 899257 (Northern Cardinal)... ✅ Generated and uploaded
# [32/692] Processing 899256 (Northern Cardinal)... ✅ Generated and uploaded
# [33/692] Processing 899245 (Northern Cardinal)... ✅ Generated and uploaded
# [34/692] Processing 894710 (Northern Cardinal)... ✅ Generated and uploaded
# [35/692] Processing 879106 (Northern Cardinal)... ✅ Generated and uploaded
# [36/692] Processing 877641 (Northern Cardinal)... ✅ Generated and uploaded
# [37/692] Processing 872638 (Northern Cardinal)... ✅ Generated and uploaded
# [38/692] Processing 872098 (Northern Cardinal)... ✅ Generated and uploaded
# [39/692] Processing 870690 (Northern Cardinal)... ✅ Generated and uploaded
# [40/692] Processing 858755 (Northern Cardinal)... ✅ Generated and uploaded
# [41/692] Processing 812577 (Northern Cardinal)... ✅ Generated and uploaded
# [42/692] Processing 809789 (Northern Cardinal)... ✅ Generated and uploaded
# [43/692] Processing 799143 (Northern Cardinal)... ✅ Generated and uploaded
# [44/692] Processing 797998 (Northern Cardinal)... ✅ Generated and uploaded
# [45/692] Processing 796781 (Northern Cardinal)... ✅ Generated and uploaded
# [46/692] Processing 793701 (Northern Cardinal)... ✅ Generated and uploaded
# [47/692] Processing 792359 (Northern Cardinal)... ✅ Generated and uploaded
# [48/692] Processing 792208 (Northern Cardinal)... ✅ Generated and uploaded
# [49/692] Processing 791092 (Northern Cardinal)... ✅ Generated and uploaded
# [50/692] Processing 788188 (Northern Cardinal)... ✅ Generated and uploaded
# [51/692] Processing 786107 (Northern Cardinal)... ✅ Generated and uploaded
# [52/692] Processing 781949 (Northern Cardinal)... ✅ Generated and uploaded
# [53/692] Processing 779378 (Northern Cardinal)... ✅ Generated and uploaded
# [54/692] Processing 778522 (Northern Cardinal)... ✅ Generated and uploaded
# [55/692] Processing 764941 (Northern Cardinal)... ✅ Generated and uploaded
# [56/692] Processing 764938 (Northern Cardinal)... ✅ Generated and uploaded
# [57/692] Processing 759257 (Northern Cardinal)... ✅ Generated and uploaded
# [58/692] Processing 759255 (Northern Cardinal)... ✅ Generated and uploaded
# [59/692] Processing 759248 (Northern Cardinal)... ✅ Generated and uploaded
# [60/692] Processing 743545 (Northern Cardinal)... ✅ Generated and uploaded
# [61/692] Processing 742592 (Northern Cardinal)... ✅ Generated and uploaded
# [62/692] Processing 742591 (Northern Cardinal)... ✅ Generated and uploaded
# [63/692] Processing 742012 (Northern Cardinal)...
# Note: Illegal Audio-MPEG-Header 0x00000000 at offset 361589.
# Note: Trying to resync...
# Note: Hit end of (available) data during resync.
# ✅ Generated and uploaded
# [64/692] Processing 740407 (Northern Cardinal)... ✅ Generated and uploaded
# [65/692] Processing 738697 (Northern Cardinal)... ✅ Generated and uploaded
# [66/692] Processing 738212 (Northern Cardinal)... ✅ Generated and uploaded
# [67/692] Processing 730976 (Northern Cardinal)... ✅ Generated and uploaded
# [68/692] Processing 727761 (Northern Cardinal)... ✅ Generated and uploaded
# [69/692] Processing 725630 (Northern Cardinal)... ✅ Generated and uploaded
# [70/692] Processing 725506 (Northern Cardinal)... ✅ Generated and uploaded
# [71/692] Processing 725505 (Northern Cardinal)... ✅ Generated and uploaded
# [72/692] Processing 725504 (Northern Cardinal)... ✅ Generated and uploaded
# [73/692] Processing 725495 (Northern Cardinal)... ✅ Generated and uploaded
# [74/692] Processing 721721 (Northern Cardinal)... ✅ Generated and uploaded
# [75/692] Processing 720913 (Northern Cardinal)... ✅ Generated and uploaded
# [76/692] Processing 718207 (Northern Cardinal)... ✅ Generated and uploaded
# [77/692] Processing 718197 (Northern Cardinal)... ✅ Generated and uploaded
# [78/692] Processing 718194 (Northern Cardinal)... ✅ Generated and uploaded
# [79/692] Processing 718150 (Northern Cardinal)... ✅ Generated and uploaded
# [80/692] Processing 718119 (Northern Cardinal)... ✅ Generated and uploaded
# [81/692] Processing 717104 (Northern Cardinal)... ✅ Generated and uploaded
# [82/692] Processing 716618 (Northern Cardinal)... ✅ Generated and uploaded
# [83/692] Processing 713583 (Northern Cardinal)... ✅ Generated and uploaded
# [84/692] Processing 709562 (Northern Cardinal)... ✅ Generated and uploaded
# [85/692] Processing 708834 (Northern Cardinal)... ✅ Generated and uploaded
# [86/692] Processing 707383 (Northern Cardinal)... ✅ Generated and uploaded
# [87/692] Processing 696751 (Northern Cardinal)... ✅ Generated and uploaded
# [88/692] Processing 691763 (Northern Cardinal)... ✅ Generated and uploaded
# [89/692] Processing 682547 (Northern Cardinal)... ✅ Generated and uploaded
# [90/692] Processing 681641 (Northern Cardinal)... ✅ Generated and uploaded
# [91/692] Processing 677300 (Northern Cardinal)... ✅ Generated and uploaded
# [92/692] Processing 667645 (Northern Cardinal)... ✅ Generated and uploaded
# [93/692] Processing 652980 (Northern Cardinal)... ✅ Generated and uploaded
# [94/692] Processing 649276 (Northern Cardinal)... ✅ Generated and uploaded
# [95/692] Processing 649261 (Northern Cardinal)... ✅ Generated and uploaded
# [96/692] Processing 642029 (Northern Cardinal)... ✅ Generated and uploaded
# [97/692] Processing 639161 (Northern Cardinal)... ✅ Generated and uploaded
# [98/692] Processing 639160 (Northern Cardinal)... ✅ Generated and uploaded
# [99/692] Processing 636561 (Northern Cardinal)... ✅ Generated and uploaded
# [100/692] Processing 636560 (Northern Cardinal)... ✅ Generated and uploaded
# [101/692] Processing 1035997 (Carolina Wren)... ✅ Generated and uploaded
# [102/692] Processing 1010648 (Carolina Wren)... ✅ Generated and uploaded
# [103/692] Processing 1004463 (Carolina Wren)... ✅ Generated and uploaded
# [104/692] Processing 995314 (Carolina Wren)... ✅ Generated and uploaded
# [105/692] Processing 951785 (Carolina Wren)... ✅ Generated and uploaded
# [106/692] Processing 951784 (Carolina Wren)... ✅ Generated and uploaded
# [107/692] Processing 951783 (Carolina Wren)... ✅ Generated and uploaded
# [108/692] Processing 951782 (Carolina Wren)... ✅ Generated and uploaded
# [109/692] Processing 951781 (Carolina Wren)... ✅ Generated and uploaded
# [110/692] Processing 941065 (Carolina Wren)... ✅ Generated and uploaded
# [111/692] Processing 938797 (Carolina Wren)... ✅ Generated and uploaded
# [112/692] Processing 929922 (Carolina Wren)... ✅ Generated and uploaded
# [113/692] Processing 923843 (Carolina Wren)... ✅ Generated and uploaded
# [114/692] Processing 923842 (Carolina Wren)... ✅ Generated and uploaded
# [115/692] Processing 923841 (Carolina Wren)... ✅ Generated and uploaded
# [116/692] Processing 923840 (Carolina Wren)... ✅ Generated and uploaded
# [117/692] Processing 923839 (Carolina Wren)... ✅ Generated and uploaded
# [118/692] Processing 923838 (Carolina Wren)... ✅ Generated and uploaded
# [119/692] Processing 923837 (Carolina Wren)... ✅ Generated and uploaded
# [120/692] Processing 923836 (Carolina Wren)... ✅ Generated and uploaded
# [121/692] Processing 923835 (Carolina Wren)... ✅ Generated and uploaded
# [122/692] Processing 905700 (Carolina Wren)... ✅ Generated and uploaded
# [123/692] Processing 900263 (Carolina Wren)... ✅ Generated and uploaded
# [124/692] Processing 899254 (Carolina Wren)... ✅ Generated and uploaded
# [125/692] Processing 899252 (Carolina Wren)... ✅ Generated and uploaded
# [126/692] Processing 896572 (Carolina Wren)... ✅ Generated and uploaded
# [127/692] Processing 893182 (Carolina Wren)... ✅ Generated and uploaded
# [128/692] Processing 884090 (Carolina Wren)... ✅ Generated and uploaded
# [129/692] Processing 880326 (Carolina Wren)... ✅ Generated and uploaded
# [130/692] Processing 880323 (Carolina Wren)... ✅ Generated and uploaded
# [131/692] Processing 879133 (Carolina Wren)... ✅ Generated and uploaded
# [132/692] Processing 855744 (Carolina Wren)... ✅ Generated and uploaded
# [133/692] Processing 842981 (Carolina Wren)... ✅ Generated and uploaded
# [134/692] Processing 840733 (Carolina Wren)... ✅ Generated and uploaded
# [135/692] Processing 828442 (Carolina Wren)... ✅ Generated and uploaded
# [136/692] Processing 828436 (Carolina Wren)... ✅ Generated and uploaded
# [137/692] Processing 828415 (Carolina Wren)... ✅ Generated and uploaded
# [138/692] Processing 820851 (Carolina Wren)... ✅ Generated and uploaded
# [139/692] Processing 805390 (Carolina Wren)... ✅ Generated and uploaded
# [140/692] Processing 803581 (Carolina Wren)... ✅ Generated and uploaded
# [141/692] Processing 793225 (Carolina Wren)... ✅ Generated and uploaded
# [142/692] Processing 792591 (Carolina Wren)... ✅ Generated and uploaded
# [143/692] Processing 792351 (Carolina Wren)... ✅ Generated and uploaded
# [144/692] Processing 738783 (Carolina Wren)... ✅ Generated and uploaded
# [145/692] Processing 735870 (Carolina Wren)... ✅ Generated and uploaded
# [146/692] Processing 729229 (Carolina Wren)... ✅ Generated and uploaded
# [147/692] Processing 723565 (Carolina Wren)... ✅ Generated and uploaded
# [148/692] Processing 723375 (Carolina Wren)... ✅ Generated and uploaded
# [149/692] Processing 723309 (Carolina Wren)... ✅ Generated and uploaded
# [150/692] Processing 713786 (Carolina Wren)... ✅ Generated and uploaded
# [151/692] Processing 703720 (Carolina Wren)... ✅ Generated and uploaded
# [152/692] Processing 692428 (Carolina Wren)... ✅ Generated and uploaded
# [153/692] Processing 692426 (Carolina Wren)... ✅ Generated and uploaded
# [154/692] Processing 683969 (Carolina Wren)... ✅ Generated and uploaded
# [155/692] Processing 682561 (Carolina Wren)... ✅ Generated and uploaded
# [156/692] Processing 682556 (Carolina Wren)... ✅ Generated and uploaded
# [157/692] Processing 682555 (Carolina Wren)... ✅ Generated and uploaded
# [158/692] Processing 668895 (Carolina Wren)... ✅ Generated and uploaded
# [159/692] Processing 668894 (Carolina Wren)... ✅ Generated and uploaded
# [160/692] Processing 655937 (Carolina Wren)... ✅ Generated and uploaded
# [161/692] Processing 654818 (Carolina Wren)... ✅ Generated and uploaded
# [162/692] Processing 637178 (Carolina Wren)... ✅ Generated and uploaded
# [163/692] Processing 601159 (Carolina Wren)... ✅ Generated and uploaded
# [164/692] Processing 600722 (Carolina Wren)... ✅ Generated and uploaded
# [165/692] Processing 600422 (Carolina Wren)... ✅ Generated and uploaded
# [166/692] Processing 598822 (Carolina Wren)... ✅ Generated and uploaded
# [167/692] Processing 593815 (Carolina Wren)... ✅ Generated and uploaded
# [168/692] Processing 585721 (Carolina Wren)... ✅ Generated and uploaded
# [169/692] Processing 583926 (Carolina Wren)... ✅ Generated and uploaded
# [170/692] Processing 581488 (Carolina Wren)... ✅ Generated and uploaded
# [171/692] Processing 578525 (Carolina Wren)... ✅ Generated and uploaded
# [172/692] Processing 574085 (Carolina Wren)... ✅ Generated and uploaded
# [173/692] Processing 573676 (Carolina Wren)... ✅ Generated and uploaded
# [174/692] Processing 572229 (Carolina Wren)... ✅ Generated and uploaded
# [175/692] Processing 572226 (Carolina Wren)... ✅ Generated and uploaded
# [176/692] Processing 572160 (Carolina Wren)... ✅ Generated and uploaded
# [177/692] Processing 570954 (Carolina Wren)... ✅ Generated and uploaded
# [178/692] Processing 570651 (Carolina Wren)... ✅ Generated and uploaded
# [179/692] Processing 570326 (Carolina Wren)... ✅ Generated and uploaded
# [180/692] Processing 569714 (Carolina Wren)... ✅ Generated and uploaded
# [181/692] Processing 569632 (Carolina Wren)... ✅ Generated and uploaded
# [182/692] Processing 569631 (Carolina Wren)... ✅ Generated and uploaded
# [183/692] Processing 568353 (Carolina Wren)... ✅ Generated and uploaded
# [184/692] Processing 567330 (Carolina Wren)... ✅ Generated and uploaded
# [185/692] Processing 564323 (Carolina Wren)... ✅ Generated and uploaded
# [186/692] Processing 564322 (Carolina Wren)... ✅ Generated and uploaded
# [187/692] Processing 564318 (Carolina Wren)... ✅ Generated and uploaded
# [188/692] Processing 563816 (Carolina Wren)... ✅ Generated and uploaded
# [189/692] Processing 563616 (Carolina Wren)... ✅ Generated and uploaded
# [190/692] Processing 563615 (Carolina Wren)... ✅ Generated and uploaded
# [191/692] Processing 563611 (Carolina Wren)... ✅ Generated and uploaded
# [192/692] Processing 563199 (Carolina Wren)... ✅ Generated and uploaded
# [193/692] Processing 562224 (Carolina Wren)... ✅ Generated and uploaded
# [194/692] Processing 562223 (Carolina Wren)... ✅ Generated and uploaded
# [195/692] Processing 562219 (Carolina Wren)... ✅ Generated and uploaded
# [196/692] Processing 558225 (Carolina Wren)... ✅ Generated and uploaded
# [197/692] Processing 556688 (Carolina Wren)... ✅ Generated and uploaded
# [198/692] Processing 556632 (Carolina Wren)... ✅ Generated and uploaded
# [199/692] Processing 556631 (Carolina Wren)... ✅ Generated and uploaded
# [200/692] Processing 1059662 (Blue Jay)... ✅ Generated and uploaded
# [201/692] Processing 1051304 (Blue Jay)... ✅ Generated and uploaded
# [202/692] Processing 1046664 (Blue Jay)... ✅ Generated and uploaded
# [203/692] Processing 1038505 (Blue Jay)... ✅ Generated and uploaded
# [204/692] Processing 1036141 (Blue Jay)... ✅ Generated and uploaded
# [205/692] Processing 1020596 (Blue Jay)... ✅ Generated and uploaded
# [206/692] Processing 1014208 (Blue Jay)... ✅ Generated and uploaded
# [207/692] Processing 1013391 (Blue Jay)... ✅ Generated and uploaded
# [208/692] Processing 1013390 (Blue Jay)... ✅ Generated and uploaded
# [209/692] Processing 1012557 (Blue Jay)... ✅ Generated and uploaded
# [210/692] Processing 1012556 (Blue Jay)... ✅ Generated and uploaded
# [211/692] Processing 1012555 (Blue Jay)... ✅ Generated and uploaded
# [212/692] Processing 1010650 (Blue Jay)... ✅ Generated and uploaded
# [213/692] Processing 1007688 (Blue Jay)... ✅ Generated and uploaded
# [214/692] Processing 994294 (Blue Jay)... ✅ Generated and uploaded
# [215/692] Processing 980359 (Blue Jay)... ✅ Generated and uploaded
# [216/692] Processing 958098 (Blue Jay)... ✅ Generated and uploaded
# [217/692] Processing 940085 (Blue Jay)... ✅ Generated and uploaded
# [218/692] Processing 938988 (Blue Jay)... ✅ Generated and uploaded
# [219/692] Processing 937346 (Blue Jay)... ✅ Generated and uploaded
# [220/692] Processing 935610 (Blue Jay)... ✅ Generated and uploaded
# [221/692] Processing 935607 (Blue Jay)... ✅ Generated and uploaded
# [222/692] Processing 933597 (Blue Jay)... ✅ Generated and uploaded
# [223/692] Processing 933596 (Blue Jay)... ✅ Generated and uploaded
# [224/692] Processing 933595 (Blue Jay)... ✅ Generated and uploaded
# [225/692] Processing 925282 (Blue Jay)... ✅ Generated and uploaded
# [226/692] Processing 924514 (Blue Jay)... ✅ Generated and uploaded
# [227/692] Processing 924410 (Blue Jay)... ✅ Generated and uploaded
# [228/692] Processing 908392 (Blue Jay)... ✅ Generated and uploaded
# [229/692] Processing 906702 (Blue Jay)... ✅ Generated and uploaded
# [230/692] Processing 899923 (Blue Jay)... ✅ Generated and uploaded
# [231/692] Processing 880466 (Blue Jay)... ✅ Generated and uploaded
# [232/692] Processing 861979 (Blue Jay)... ✅ Generated and uploaded
# [233/692] Processing 841327 (Blue Jay)... ✅ Generated and uploaded
# [234/692] Processing 839184 (Blue Jay)... ✅ Generated and uploaded
# [235/692] Processing 833840 (Blue Jay)... ✅ Generated and uploaded
# [236/692] Processing 817559 (Blue Jay)... ✅ Generated and uploaded
# [237/692] Processing 817558 (Blue Jay)... ✅ Generated and uploaded
# [238/692] Processing 817557 (Blue Jay)... ✅ Generated and uploaded
# [239/692] Processing 817555 (Blue Jay)... ✅ Generated and uploaded
# [240/692] Processing 809927 (Blue Jay)... ✅ Generated and uploaded
# [241/692] Processing 804808 (Blue Jay)... ✅ Generated and uploaded
# [242/692] Processing 792176 (Blue Jay)... ✅ Generated and uploaded
# [243/692] Processing 760145 (Blue Jay)... ✅ Generated and uploaded
# [244/692] Processing 760144 (Blue Jay)... ✅ Generated and uploaded
# [245/692] Processing 757631 (Blue Jay)... ✅ Generated and uploaded
# [246/692] Processing 754448 (Blue Jay)... ✅ Generated and uploaded
# [247/692] Processing 747012 (Blue Jay)... ✅ Generated and uploaded
# [248/692] Processing 734887 (Blue Jay)... ✅ Generated and uploaded
# [249/692] Processing 721248 (Blue Jay)... ✅ Generated and uploaded
# [250/692] Processing 721247 (Blue Jay)... ✅ Generated and uploaded
# [251/692] Processing 712978 (Blue Jay)... ✅ Generated and uploaded
# [252/692] Processing 712977 (Blue Jay)... ✅ Generated and uploaded
# [253/692] Processing 711502 (Blue Jay)... ✅ Generated and uploaded
# [254/692] Processing 696752 (Blue Jay)... ✅ Generated and uploaded
# [255/692] Processing 696440 (Blue Jay)... ✅ Generated and uploaded
# [256/692] Processing 696438 (Blue Jay)... ✅ Generated and uploaded
# [257/692] Processing 694236 (Blue Jay)... ✅ Generated and uploaded
# [258/692] Processing 691957 (Blue Jay)... ✅ Generated and uploaded
# [259/692] Processing 691163 (Blue Jay)... ✅ Generated and uploaded
# [260/692] Processing 691162 (Blue Jay)... ✅ Generated and uploaded
# [261/692] Processing 691161 (Blue Jay)... ✅ Generated and uploaded
# [262/692] Processing 691160 (Blue Jay)... ✅ Generated and uploaded
# [263/692] Processing 691159 (Blue Jay)... ✅ Generated and uploaded
# [264/692] Processing 691158 (Blue Jay)... ✅ Generated and uploaded
# [265/692] Processing 640351 (Blue Jay)... ✅ Generated and uploaded
# [266/692] Processing 640349 (Blue Jay)... ✅ Generated and uploaded
# [267/692] Processing 638324 (Blue Jay)... ✅ Generated and uploaded
# [268/692] Processing 638323 (Blue Jay)... ✅ Generated and uploaded
# [269/692] Processing 638296 (Blue Jay)... ✅ Generated and uploaded
# [270/692] Processing 636535 (Blue Jay)... ✅ Generated and uploaded
# [271/692] Processing 632164 (Blue Jay)... ✅ Generated and uploaded
# [272/692] Processing 629110 (Blue Jay)... ✅ Generated and uploaded
# [273/692] Processing 622245 (Blue Jay)... ✅ Generated and uploaded
# [274/692] Processing 621792 (Blue Jay)... ✅ Generated and uploaded
# [275/692] Processing 615045 (Blue Jay)... ✅ Generated and uploaded
# [276/692] Processing 605642 (Blue Jay)... ✅ Generated and uploaded
# [277/692] Processing 600535 (Blue Jay)... ✅ Generated and uploaded
# [278/692] Processing 600532 (Blue Jay)... ✅ Generated and uploaded
# [279/692] Processing 592263 (Blue Jay)... ✅ Generated and uploaded
# [280/692] Processing 590983 (Blue Jay)... ✅ Generated and uploaded
# [281/692] Processing 589307 (Blue Jay)... ✅ Generated and uploaded
# [282/692] Processing 587488 (Blue Jay)... ✅ Generated and uploaded
# [283/692] Processing 587334 (Blue Jay)... ✅ Generated and uploaded
# [284/692] Processing 586549 (Blue Jay)... ✅ Generated and uploaded
# [285/692] Processing 580991 (Blue Jay)... ✅ Generated and uploaded
# [286/692] Processing 573211 (Blue Jay)... ✅ Generated and uploaded
# [287/692] Processing 572588 (Blue Jay)... ✅ Generated and uploaded
# [288/692] Processing 571792 (Blue Jay)... ✅ Generated and uploaded
# [289/692] Processing 570570 (Blue Jay)... ✅ Generated and uploaded
# [290/692] Processing 570216 (Blue Jay)... ✅ Generated and uploaded
# [291/692] Processing 564002 (Blue Jay)... ✅ Generated and uploaded
# [292/692] Processing 562454 (Blue Jay)... ✅ Generated and uploaded
# [293/692] Processing 559474 (Blue Jay)... ✅ Generated and uploaded
# [294/692] Processing 558249 (Blue Jay)... ✅ Generated and uploaded
# [295/692] Processing 549777 (Blue Jay)...
# Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# ✅ Generated and uploaded
# [296/692] Processing 549775 (Blue Jay)... ✅ Generated and uploaded
# [297/692] Processing 530848 (Blue Jay)... ✅ Generated and uploaded
# [298/692] Processing 521284 (Blue Jay)... ✅ Generated and uploaded
# [299/692] Processing 511960 (Blue Jay)... ✅ Generated and uploaded
# [300/692] Processing 1068477 (American Robin)... ✅ Generated and uploaded
# [301/692] Processing 1049493 (American Robin)... ✅ Generated and uploaded
# [302/692] Processing 1047670 (American Robin)... ✅ Generated and uploaded
# [303/692] Processing 1046358 (American Robin)... ✅ Generated and uploaded
# [304/692] Processing 1045448 (American Robin)... ✅ Generated and uploaded
# [305/692] Processing 1023056 (American Robin)... ✅ Generated and uploaded
# [306/692] Processing 1023050 (American Robin)... ✅ Generated and uploaded
# [307/692] Processing 1013854 (American Robin)... ✅ Generated and uploaded
# [308/692] Processing 1012677 (American Robin)... ✅ Generated and uploaded
# [309/692] Processing 1012675 (American Robin)... ✅ Generated and uploaded
# [310/692] Processing 1010651 (American Robin)... ✅ Generated and uploaded
# [311/692] Processing 1005778 (American Robin)... ✅ Generated and uploaded
# [312/692] Processing 999808 (American Robin)... ✅ Generated and uploaded
# [313/692] Processing 999643 (American Robin)... ✅ Generated and uploaded
# [314/692] Processing 999642 (American Robin)... ✅ Generated and uploaded
# [315/692] Processing 999597 (American Robin)... ✅ Generated and uploaded
# [316/692] Processing 959619 (American Robin)... ✅ Generated and uploaded
# [317/692] Processing 954703 (American Robin)... ✅ Generated and uploaded
# [318/692] Processing 938991 (American Robin)... ✅ Generated and uploaded
# [319/692] Processing 914376 (American Robin)... ✅ Generated and uploaded
# [320/692] Processing 914374 (American Robin)... ✅ Generated and uploaded
# [321/692] Processing 892933 (American Robin)... ✅ Generated and uploaded
# [322/692] Processing 880805 (American Robin)... ✅ Generated and uploaded
# [323/692] Processing 880802 (American Robin)... ✅ Generated and uploaded
# [324/692] Processing 872369 (American Robin)... ✅ Generated and uploaded
# [325/692] Processing 860362 (American Robin)... ✅ Generated and uploaded
# [326/692] Processing 825256 (American Robin)... ✅ Generated and uploaded
# [327/692] Processing 825254 (American Robin)... ✅ Generated and uploaded
# [328/692] Processing 803375 (American Robin)... ✅ Generated and uploaded
# [329/692] Processing 789575 (American Robin)... ✅ Generated and uploaded
# [330/692] Processing 779498 (American Robin)... ✅ Generated and uploaded
# [331/692] Processing 779497 (American Robin)... ✅ Generated and uploaded
# [332/692] Processing 774170 (American Robin)... ✅ Generated and uploaded
# [333/692] Processing 774161 (American Robin)... ✅ Generated and uploaded
# [334/692] Processing 772840 (American Robin)... ✅ Generated and uploaded
# [335/692] Processing 771921 (American Robin)... ✅ Generated and uploaded
# [336/692] Processing 771920 (American Robin)... ✅ Generated and uploaded
# [337/692] Processing 752952 (American Robin)... ✅ Generated and uploaded
# [338/692] Processing 749773 (American Robin)... ✅ Generated and uploaded
# [339/692] Processing 744618 (American Robin)... ✅ Generated and uploaded
# [340/692] Processing 744610 (American Robin)... ✅ Generated and uploaded
# [341/692] Processing 744275 (American Robin)... ✅ Generated and uploaded
# [342/692] Processing 742848 (American Robin)... ✅ Generated and uploaded
# [343/692] Processing 736763 (American Robin)... ✅ Generated and uploaded
# [344/692] Processing 734182 (American Robin)... ✅ Generated and uploaded
# [345/692] Processing 734125 (American Robin)... ✅ Generated and uploaded
# [346/692] Processing 729934 (American Robin)... ✅ Generated and uploaded
# [347/692] Processing 729933 (American Robin)... ✅ Generated and uploaded
# [348/692] Processing 728269 (American Robin)... ✅ Generated and uploaded
# [349/692] Processing 723888 (American Robin)... ✅ Generated and uploaded
# [350/692] Processing 722625 (American Robin)... ✅ Generated and uploaded
# [351/692] Processing 720932 (American Robin)... ✅ Generated and uploaded
# [352/692] Processing 716282 (American Robin)... ✅ Generated and uploaded
# [353/692] Processing 713003 (American Robin)... ✅ Generated and uploaded
# [354/692] Processing 711105 (American Robin)... ✅ Generated and uploaded
# [355/692] Processing 710116 (American Robin)... ✅ Generated and uploaded
# [356/692] Processing 698509 (American Robin)... ✅ Generated and uploaded
# [357/692] Processing 690092 (American Robin)... ✅ Generated and uploaded
# [358/692] Processing 686190 (American Robin)... ✅ Generated and uploaded
# [359/692] Processing 666135 (American Robin)... ✅ Generated and uploaded
# [360/692] Processing 663098 (American Robin)... ✅ Generated and uploaded
# [361/692] Processing 663094 (American Robin)... ✅ Generated and uploaded
# [362/692] Processing 663093 (American Robin)... ✅ Generated and uploaded
# [363/692] Processing 660898 (American Robin)... ✅ Generated and uploaded
# [364/692] Processing 656426 (American Robin)... ✅ Generated and uploaded
# [365/692] Processing 651831 (American Robin)... ✅ Generated and uploaded
# [366/692] Processing 649580 (American Robin)... ✅ Generated and uploaded
# [367/692] Processing 649134 (American Robin)... ✅ Generated and uploaded
# [368/692] Processing 647155 (American Robin)... ✅ Generated and uploaded
# [369/692] Processing 647154 (American Robin)... ✅ Generated and uploaded
# [370/692] Processing 645161 (American Robin)... ✅ Generated and uploaded
# [371/692] Processing 641669 (American Robin)... ✅ Generated and uploaded
# [372/692] Processing 641578 (American Robin)... ✅ Generated and uploaded
# [373/692] Processing 640975 (American Robin)... ✅ Generated and uploaded
# [374/692] Processing 639265 (American Robin)... ✅ Generated and uploaded
# [375/692] Processing 638326 (American Robin)... ✅ Generated and uploaded
# [376/692] Processing 636519 (American Robin)... ✅ Generated and uploaded
# [377/692] Processing 636181 (American Robin)... ✅ Generated and uploaded
# [378/692] Processing 635395 (American Robin)... ✅ Generated and uploaded
# [379/692] Processing 624425 (American Robin)... ✅ Generated and uploaded
# [380/692] Processing 610952 (American Robin)... ✅ Generated and uploaded
# [381/692] Processing 610883 (American Robin)... ✅ Generated and uploaded
# [382/692] Processing 599316 (American Robin)... ✅ Generated and uploaded
# [383/692] Processing 574494 (American Robin)... ✅ Generated and uploaded
# [384/692] Processing 574489 (American Robin)... ✅ Generated and uploaded
# [385/692] Processing 574487 (American Robin)... ✅ Generated and uploaded
# [386/692] Processing 574486 (American Robin)... ✅ Generated and uploaded
# [387/692] Processing 574484 (American Robin)... ✅ Generated and uploaded
# [388/692] Processing 574483 (American Robin)... ✅ Generated and uploaded
# [389/692] Processing 574482 (American Robin)... ✅ Generated and uploaded
# [390/692] Processing 574476 (American Robin)... ✅ Generated and uploaded
# [391/692] Processing 574473 (American Robin)... ✅ Generated and uploaded
# [392/692] Processing 574471 (American Robin)... ✅ Generated and uploaded
# [393/692] Processing 574469 (American Robin)... ✅ Generated and uploaded
# [394/692] Processing 574466 (American Robin)... ✅ Generated and uploaded
# [395/692] Processing 574171 (American Robin)... ✅ Generated and uploaded
# [396/692] Processing 573924 (American Robin)... ✅ Generated and uploaded
# [397/692] Processing 572715 (American Robin)... ✅ Generated and uploaded
# [398/692] Processing 572223 (American Robin)... ✅ Generated and uploaded
# [399/692] Processing 572222 (American Robin)... ✅ Generated and uploaded
# [400/692] Processing 1013493 (Mourning Dove)... ✅ Generated and uploaded
# [401/692] Processing 1013012 (Mourning Dove)... ✅ Generated and uploaded
# [402/692] Processing 995960 (Mourning Dove)... ✅ Generated and uploaded
# [403/692] Processing 995959 (Mourning Dove)... ✅ Generated and uploaded
# [404/692] Processing 995957 (Mourning Dove)... ✅ Generated and uploaded
# [405/692] Processing 940517 (Mourning Dove)... ✅ Generated and uploaded
# [406/692] Processing 807126 (Mourning Dove)... ✅ Generated and uploaded
# [407/692] Processing 767710 (Mourning Dove)... ✅ Generated and uploaded
# [408/692] Processing 696289 (Mourning Dove)... ✅ Generated and uploaded
# [409/692] Processing 691623 (Mourning Dove)... ✅ Generated and uploaded
# [410/692] Processing 661720 (Mourning Dove)... ✅ Generated and uploaded
# [411/692] Processing 638304 (Mourning Dove)... ✅ Generated and uploaded
# [412/692] Processing 636552 (Mourning Dove)... ✅ Generated and uploaded
# [413/692] Processing 621378 (Mourning Dove)... ✅ Generated and uploaded
# [414/692] Processing 621377 (Mourning Dove)... ✅ Generated and uploaded
# [415/692] Processing 621374 (Mourning Dove)... ✅ Generated and uploaded
# [416/692] Processing 613539 (Mourning Dove)... ✅ Generated and uploaded
# [417/692] Processing 583581 (Mourning Dove)... ✅ Generated and uploaded
# [418/692] Processing 583580 (Mourning Dove)... ✅ Generated and uploaded
# [419/692] Processing 583577 (Mourning Dove)... ✅ Generated and uploaded
# [420/692] Processing 583575 (Mourning Dove)... ✅ Generated and uploaded
# [421/692] Processing 583574 (Mourning Dove)... ✅ Generated and uploaded
# [422/692] Processing 580701 (Mourning Dove)... ✅ Generated and uploaded
# [423/692] Processing 495471 (Mourning Dove)... ✅ Generated and uploaded
# [424/692] Processing 493300 (Mourning Dove)... ✅ Generated and uploaded
# [425/692] Processing 476933 (Mourning Dove)... ✅ Generated and uploaded
# [426/692] Processing 459335 (Mourning Dove)... ✅ Generated and uploaded
# [427/692] Processing 451819 (Mourning Dove)... ✅ Generated and uploaded
# [428/692] Processing 430095 (Mourning Dove)... ✅ Generated and uploaded
# [429/692] Processing 407859 (Mourning Dove)... ✅ Generated and uploaded
# [430/692] Processing 382741 (Mourning Dove)... ✅ Generated and uploaded
# [431/692] Processing 381111 (Mourning Dove)... ✅ Generated and uploaded
# [432/692] Processing 349471 (Mourning Dove)... ✅ Generated and uploaded
# [433/692] Processing 268216 (Mourning Dove)... ✅ Generated and uploaded
# [434/692] Processing 268211 (Mourning Dove)... ✅ Generated and uploaded
# [435/692] Processing 268209 (Mourning Dove)... ✅ Generated and uploaded
# [436/692] Processing 268208 (Mourning Dove)... ✅ Generated and uploaded
# [437/692] Processing 268207 (Mourning Dove)... ✅ Generated and uploaded
# [438/692] Processing 268206 (Mourning Dove)... ✅ Generated and uploaded
# [439/692] Processing 179721 (Mourning Dove)... ✅ Generated and uploaded
# [440/692] Processing 153654 (Mourning Dove)... ✅ Generated and uploaded
# [441/692] Processing 153653 (Mourning Dove)... ✅ Generated and uploaded
# [442/692] Processing 153652 (Mourning Dove)... ✅ Generated and uploaded
# [443/692] Processing 153651 (Mourning Dove)... ✅ Generated and uploaded
# [444/692] Processing 153648 (Mourning Dove)... ✅ Generated and uploaded
# [445/692] Processing 153645 (Mourning Dove)... ✅ Generated and uploaded
# [446/692] Processing 153639 (Mourning Dove)... ✅ Generated and uploaded
# [447/692] Processing 131448 (Mourning Dove)... ✅ Generated and uploaded
# [448/692] Processing 109033 (Mourning Dove)... ✅ Generated and uploaded
# [449/692] Processing 46669 (Mourning Dove)... ✅ Generated and uploaded
# [450/692] Processing 35102 (Mourning Dove)... ✅ Generated and uploaded
# [451/692] Processing 35100 (Mourning Dove)... ✅ Generated and uploaded
# [452/692] Processing 14872 (Mourning Dove)... ✅ Generated and uploaded
# [453/692] Processing 14871 (Mourning Dove)... ✅ Generated and uploaded
# [454/692] Processing 1035994 (Tufted Titmouse)... ✅ Generated and uploaded
# [455/692] Processing 1027848 (Tufted Titmouse)... ✅ Generated and uploaded
# [456/692] Processing 1014938 (Tufted Titmouse)... ✅ Generated and uploaded
# [457/692] Processing 1014937 (Tufted Titmouse)... ✅ Generated and uploaded
# [458/692] Processing 1010613 (Tufted Titmouse)... ✅ Generated and uploaded
# [459/692] Processing 951797 (Tufted Titmouse)... ✅ Generated and uploaded
# [460/692] Processing 951796 (Tufted Titmouse)... ✅ Generated and uploaded
# [461/692] Processing 941253 (Tufted Titmouse)... ✅ Generated and uploaded
# [462/692] Processing 900409 (Tufted Titmouse)... ✅ Generated and uploaded
# [463/692] Processing 899085 (Tufted Titmouse)... ✅ Generated and uploaded
# [464/692] Processing 895984 (Tufted Titmouse)... ✅ Generated and uploaded
# [465/692] Processing 895279 (Tufted Titmouse)... ✅ Generated and uploaded
# [466/692] Processing 884288 (Tufted Titmouse)... ✅ Generated and uploaded
# [467/692] Processing 879235 (Tufted Titmouse)... ✅ Generated and uploaded
# [468/692] Processing 879234 (Tufted Titmouse)... ✅ Generated and uploaded
# [469/692] Processing 879233 (Tufted Titmouse)... ✅ Generated and uploaded
# [470/692] Processing 879232 (Tufted Titmouse)... ✅ Generated and uploaded
# [471/692] Processing 879231 (Tufted Titmouse)... ✅ Generated and uploaded
# [472/692] Processing 875276 (Tufted Titmouse)... ✅ Generated and uploaded
# [473/692] Processing 861595 (Tufted Titmouse)... ✅ Generated and uploaded
# [474/692] Processing 827249 (Tufted Titmouse)... ✅ Generated and uploaded
# [475/692] Processing 827248 (Tufted Titmouse)... ✅ Generated and uploaded
# [476/692] Processing 827247 (Tufted Titmouse)... ✅ Generated and uploaded
# [477/692] Processing 827245 (Tufted Titmouse)... ✅ Generated and uploaded
# [478/692] Processing 827244 (Tufted Titmouse)... ✅ Generated and uploaded
# [479/692] Processing 827241 (Tufted Titmouse)... ✅ Generated and uploaded
# [480/692] Processing 827240 (Tufted Titmouse)... ✅ Generated and uploaded
# [481/692] Processing 814179 (Tufted Titmouse)... ✅ Generated and uploaded
# [482/692] Processing 814177 (Tufted Titmouse)... ✅ Generated and uploaded
# [483/692] Processing 793408 (Tufted Titmouse)... ✅ Generated and uploaded
# [484/692] Processing 785277 (Tufted Titmouse)... ✅ Generated and uploaded
# [485/692] Processing 781968 (Tufted Titmouse)... ✅ Generated and uploaded
# [486/692] Processing 713584 (Tufted Titmouse)... ✅ Generated and uploaded
# [487/692] Processing 713261 (Tufted Titmouse)... ✅ Generated and uploaded
# [488/692] Processing 713258 (Tufted Titmouse)... ✅ Generated and uploaded
# [489/692] Processing 712980 (Tufted Titmouse)... ✅ Generated and uploaded
# [490/692] Processing 706242 (Tufted Titmouse)... ✅ Generated and uploaded
# [491/692] Processing 703749 (Tufted Titmouse)... ✅ Generated and uploaded
# [492/692] Processing 701551 (Tufted Titmouse)... ✅ Generated and uploaded
# [493/692] Processing 692191 (Tufted Titmouse)... ✅ Generated and uploaded
# [494/692] Processing 649331 (Tufted Titmouse)... ✅ Generated and uploaded
# [495/692] Processing 627685 (Tufted Titmouse)... ✅ Generated and uploaded
# [496/692] Processing 624947 (Tufted Titmouse)... ✅ Generated and uploaded
# [497/692] Processing 623003 (Tufted Titmouse)... ✅ Generated and uploaded
# [498/692] Processing 600069 (Tufted Titmouse)... ✅ Generated and uploaded
# [499/692] Processing 591473 (Tufted Titmouse)... ✅ Generated and uploaded
# [500/692] Processing 590611 (Tufted Titmouse)... ✅ Generated and uploaded
# [501/692] Processing 572390 (Tufted Titmouse)... ✅ Generated and uploaded
# [502/692] Processing 572375 (Tufted Titmouse)...
# Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# ✅ Generated and uploaded
# [503/692] Processing 569728 (Tufted Titmouse)... ✅ Generated and uploaded
# [504/692] Processing 568906 (Tufted Titmouse)... ✅ Generated and uploaded
# [505/692] Processing 562016 (Tufted Titmouse)... ✅ Generated and uploaded
# [506/692] Processing 556166 (Tufted Titmouse)... ✅ Generated and uploaded
# [507/692] Processing 544303 (Tufted Titmouse)... ✅ Generated and uploaded
# [508/692] Processing 529792 (Tufted Titmouse)... ✅ Generated and uploaded
# [509/692] Processing 522855 (Tufted Titmouse)... ✅ Generated and uploaded
# [510/692] Processing 501232 (Tufted Titmouse)... ✅ Generated and uploaded
# [511/692] Processing 501231 (Tufted Titmouse)... ✅ Generated and uploaded
# [512/692] Processing 499563 (Tufted Titmouse)... ✅ Generated and uploaded
# [513/692] Processing 479486 (Tufted Titmouse)... ✅ Generated and uploaded
# [514/692] Processing 469655 (Tufted Titmouse)... ✅ Generated and uploaded
# [515/692] Processing 469582 (Tufted Titmouse)... ✅ Generated and uploaded
# [516/692] Processing 467635 (Tufted Titmouse)... ✅ Generated and uploaded
# [517/692] Processing 465256 (Tufted Titmouse)... ✅ Generated and uploaded
# [518/692] Processing 465058 (Tufted Titmouse)... ✅ Generated and uploaded
# [519/692] Processing 463360 (Tufted Titmouse)...
# Warning: Xing stream size off by more than 1%, fuzzy seeking may be even more fuzzy than by design!
# ✅ Generated and uploaded
# [520/692] Processing 446662 (Tufted Titmouse)... ✅ Generated and uploaded
# [521/692] Processing 428278 (Tufted Titmouse)... ✅ Generated and uploaded
# [522/692] Processing 422042 (Tufted Titmouse)... ✅ Generated and uploaded
# [523/692] Processing 385825 (Tufted Titmouse)... ✅ Generated and uploaded
# [524/692] Processing 375008 (Tufted Titmouse)... ✅ Generated and uploaded
# [525/692] Processing 363065 (Tufted Titmouse)...
# Note: Illegal Audio-MPEG-Header 0x454e5245 at offset 621840.
# Note: Trying to resync...
# Note: Hit end of (available) data during resync.
# ✅ Generated and uploaded
# [526/692] Processing 348110 (Tufted Titmouse)... ✅ Generated and uploaded
# [527/692] Processing 333285 (Tufted Titmouse)... ✅ Generated and uploaded
# [528/692] Processing 322769 (Tufted Titmouse)... ✅ Generated and uploaded
# [529/692] Processing 318897 (Tufted Titmouse)... ✅ Generated and uploaded
# [530/692] Processing 316285 (Tufted Titmouse)... ✅ Generated and uploaded
# [531/692] Processing 313159 (Tufted Titmouse)... ✅ Generated and uploaded
# [532/692] Processing 311712 (Tufted Titmouse)... ✅ Generated and uploaded
# [533/692] Processing 310835 (Tufted Titmouse)... ✅ Generated and uploaded
# [534/692] Processing 309396 (Tufted Titmouse)... ✅ Generated and uploaded
# [535/692] Processing 308401 (Tufted Titmouse)... ✅ Generated and uploaded
# [536/692] Processing 306851 (Tufted Titmouse)... ✅ Generated and uploaded
# [537/692] Processing 305136 (Tufted Titmouse)... ✅ Generated and uploaded
# [538/692] Processing 305015 (Tufted Titmouse)... ✅ Generated and uploaded
# [539/692] Processing 299474 (Tufted Titmouse)... ✅ Generated and uploaded
# [540/692] Processing 290151 (Tufted Titmouse)... ✅ Generated and uploaded
# [541/692] Processing 236017 (Tufted Titmouse)... ✅ Generated and uploaded
# [542/692] Processing 196755 (Tufted Titmouse)... ✅ Generated and uploaded
# [543/692] Processing 174892 (Tufted Titmouse)... ✅ Generated and uploaded
# [544/692] Processing 174397 (Tufted Titmouse)... ✅ Generated and uploaded
# [545/692] Processing 172590 (Tufted Titmouse)... ✅ Generated and uploaded
# [546/692] Processing 168057 (Tufted Titmouse)... ✅ Generated and uploaded
# [547/692] Processing 164758 (Tufted Titmouse)... ✅ Generated and uploaded
# [548/692] Processing 145941 (Tufted Titmouse)... ✅ Generated and uploaded
# [549/692] Processing 145938 (Tufted Titmouse)... ✅ Generated and uploaded
# [550/692] Processing 101646 (Tufted Titmouse)... ✅ Generated and uploaded
# [551/692] Processing 97374 (Tufted Titmouse)... ✅ Generated and uploaded
# [552/692] Processing 60068 (Tufted Titmouse)... ✅ Generated and uploaded
# [553/692] Processing 59158 (Tufted Titmouse)... ✅ Generated and uploaded
# [554/692] Processing 1010608 (Carolina Chickadee)... ✅ Generated and uploaded
# [555/692] Processing 959878 (Carolina Chickadee)... ✅ Generated and uploaded
# [556/692] Processing 955910 (Carolina Chickadee)... ✅ Generated and uploaded
# [557/692] Processing 955593 (Carolina Chickadee)... ✅ Generated and uploaded
# [558/692] Processing 938770 (Carolina Chickadee)... ✅ Generated and uploaded
# [559/692] Processing 933606 (Carolina Chickadee)... ✅ Generated and uploaded
# [560/692] Processing 933605 (Carolina Chickadee)... ✅ Generated and uploaded
# [561/692] Processing 933604 (Carolina Chickadee)... ✅ Generated and uploaded
# [562/692] Processing 884282 (Carolina Chickadee)... ✅ Generated and uploaded
# [563/692] Processing 877923 (Carolina Chickadee)... ✅ Generated and uploaded
# [564/692] Processing 877922 (Carolina Chickadee)... ✅ Generated and uploaded
# [565/692] Processing 877921 (Carolina Chickadee)... ✅ Generated and uploaded
# [566/692] Processing 877920 (Carolina Chickadee)... ✅ Generated and uploaded
# [567/692] Processing 877919 (Carolina Chickadee)... ✅ Generated and uploaded
# [568/692] Processing 877918 (Carolina Chickadee)... ✅ Generated and uploaded
# [569/692] Processing 877917 (Carolina Chickadee)... ✅ Generated and uploaded
# [570/692] Processing 877868 (Carolina Chickadee)... ✅ Generated and uploaded
# [571/692] Processing 871064 (Carolina Chickadee)... ✅ Generated and uploaded
# [572/692] Processing 871058 (Carolina Chickadee)... ✅ Generated and uploaded
# [573/692] Processing 870687 (Carolina Chickadee)... ✅ Generated and uploaded
# [574/692] Processing 870686 (Carolina Chickadee)... ✅ Generated and uploaded
# [575/692] Processing 862284 (Carolina Chickadee)... ✅ Generated and uploaded
# [576/692] Processing 861741 (Carolina Chickadee)... ✅ Generated and uploaded
# [577/692] Processing 814918 (Carolina Chickadee)... ✅ Generated and uploaded
# [578/692] Processing 814916 (Carolina Chickadee)... ✅ Generated and uploaded
# [579/692] Processing 807462 (Carolina Chickadee)... ✅ Generated and uploaded
# [580/692] Processing 796340 (Carolina Chickadee)... ✅ Generated and uploaded
# [581/692] Processing 734763 (Carolina Chickadee)... ✅ Generated and uploaded
# [582/692] Processing 717444 (Carolina Chickadee)... ✅ Generated and uploaded
# [583/692] Processing 616706 (Carolina Chickadee)... ✅ Generated and uploaded
# [584/692] Processing 606052 (Carolina Chickadee)... ✅ Generated and uploaded
# [585/692] Processing 572217 (Carolina Chickadee)... ✅ Generated and uploaded
# [586/692] Processing 572215 (Carolina Chickadee)... ✅ Generated and uploaded
# [587/692] Processing 571268 (Carolina Chickadee)... ✅ Generated and uploaded
# [588/692] Processing 566447 (Carolina Chickadee)... ✅ Generated and uploaded
# [589/692] Processing 483022 (Carolina Chickadee)...
# Note: Illegal Audio-MPEG-Header 0x6e736973 at offset 186880.
# Note: Trying to resync...
# Note: Hit end of (available) data during resync.
# ✅ Generated and uploaded
# [590/692] Processing 466694 (Carolina Chickadee)... ✅ Generated and uploaded
# [591/692] Processing 452616 (Carolina Chickadee)... ✅ Generated and uploaded
# [592/692] Processing 391442 (Carolina Chickadee)... ✅ Generated and uploaded
# [593/692] Processing 391432 (Carolina Chickadee)... ✅ Generated and uploaded
# [594/692] Processing 391431 (Carolina Chickadee)... ✅ Generated and uploaded
# [595/692] Processing 366600 (Carolina Chickadee)... ✅ Generated and uploaded
# [596/692] Processing 364473 (Carolina Chickadee)... ✅ Generated and uploaded
# [597/692] Processing 362250 (Carolina Chickadee)... ✅ Generated and uploaded
# [598/692] Processing 360934 (Carolina Chickadee)... ✅ Generated and uploaded
# [599/692] Processing 339932 (Carolina Chickadee)... ✅ Generated and uploaded
# [600/692] Processing 310196 (Carolina Chickadee)... ✅ Generated and uploaded
# [601/692] Processing 309927 (Carolina Chickadee)... ✅ Generated and uploaded
# [602/692] Processing 309925 (Carolina Chickadee)... ✅ Generated and uploaded
# [603/692] Processing 309487 (Carolina Chickadee)... ✅ Generated and uploaded
# [604/692] Processing 232860 (Carolina Chickadee)... ✅ Generated and uploaded
# [605/692] Processing 227271 (Carolina Chickadee)... ✅ Generated and uploaded
# [606/692] Processing 227270 (Carolina Chickadee)... ✅ Generated and uploaded
# [607/692] Processing 172591 (Carolina Chickadee)... ✅ Generated and uploaded
# [608/692] Processing 167824 (Carolina Chickadee)... ✅ Generated and uploaded
# [609/692] Processing 154971 (Carolina Chickadee)... ✅ Generated and uploaded
# [610/692] Processing 138604 (Carolina Chickadee)... ✅ Generated and uploaded
# [611/692] Processing 123410 (Carolina Chickadee)... ✅ Generated and uploaded
# [612/692] Processing 123408 (Carolina Chickadee)... ✅ Generated and uploaded
# [613/692] Processing 121934 (Carolina Chickadee)... ✅ Generated and uploaded
# [614/692] Processing 121933 (Carolina Chickadee)... ✅ Generated and uploaded
# [615/692] Processing 121932 (Carolina Chickadee)... ✅ Generated and uploaded
# [616/692] Processing 121930 (Carolina Chickadee)... ✅ Generated and uploaded
# [617/692] Processing 121929 (Carolina Chickadee)... ✅ Generated and uploaded
# [618/692] Processing 112633 (Carolina Chickadee)... ✅ Generated and uploaded
# [619/692] Processing 112510 (Carolina Chickadee)... ✅ Generated and uploaded
# [620/692] Processing 111140 (Carolina Chickadee)... ✅ Generated and uploaded
# [621/692] Processing 70980 (Carolina Chickadee)... ✅ Generated and uploaded
# [622/692] Processing 57446 (Carolina Chickadee)... ✅ Generated and uploaded
# [623/692] Processing 57445 (Carolina Chickadee)... ✅ Generated and uploaded
# [624/692] Processing 57321 (Carolina Chickadee)... ✅ Generated and uploaded
# [625/692] Processing 34951 (Carolina Chickadee)... ✅ Generated and uploaded
# [626/692] Processing 34950 (Carolina Chickadee)... ✅ Generated and uploaded
# [627/692] Processing 33598 (Carolina Chickadee)... ✅ Generated and uploaded
# [628/692] Processing 18446 (Carolina Chickadee)... ✅ Generated and uploaded
# [629/692] Processing 18445 (Carolina Chickadee)... ✅ Generated and uploaded
# [630/692] Processing 15190 (Carolina Chickadee)... ✅ Generated and uploaded
# [631/692] Processing 15189 (Carolina Chickadee)... ✅ Generated and uploaded
# [632/692] Processing 1059664 (Eastern Bluebird)... ✅ Generated and uploaded
# [633/692] Processing 1045482 (Eastern Bluebird)... ✅ Generated and uploaded
# [634/692] Processing 1027243 (Eastern Bluebird)... ✅ Generated and uploaded
# [635/692] Processing 1014698 (Eastern Bluebird)... ✅ Generated and uploaded
# [636/692] Processing 1014697 (Eastern Bluebird)... ✅ Generated and uploaded
# [637/692] Processing 1014696 (Eastern Bluebird)... ✅ Generated and uploaded
# [638/692] Processing 890154 (Eastern Bluebird)... ✅ Generated and uploaded
# [639/692] Processing 890151 (Eastern Bluebird)... ✅ Generated and uploaded
# [640/692] Processing 890150 (Eastern Bluebird)... ✅ Generated and uploaded
# [641/692] Processing 890146 (Eastern Bluebird)... ✅ Generated and uploaded
# [642/692] Processing 844282 (Eastern Bluebird)... ✅ Generated and uploaded
# [643/692] Processing 824503 (Eastern Bluebird)... ✅ Generated and uploaded
# [644/692] Processing 712412 (Eastern Bluebird)... ✅ Generated and uploaded
# [645/692] Processing 638302 (Eastern Bluebird)... ✅ Generated and uploaded
# [646/692] Processing 626711 (Eastern Bluebird)... ✅ Generated and uploaded
# [647/692] Processing 608740 (Eastern Bluebird)... ✅ Generated and uploaded
# [648/692] Processing 604632 (Eastern Bluebird)... ✅ Generated and uploaded
# [649/692] Processing 601013 (Eastern Bluebird)... ✅ Generated and uploaded
# [650/692] Processing 601011 (Eastern Bluebird)... ✅ Generated and uploaded
# [651/692] Processing 601010 (Eastern Bluebird)... ✅ Generated and uploaded
# [652/692] Processing 599325 (Eastern Bluebird)... ✅ Generated and uploaded
# [653/692] Processing 589468 (Eastern Bluebird)... ✅ Generated and uploaded
# [654/692] Processing 570650 (Eastern Bluebird)... ✅ Generated and uploaded
# [655/692] Processing 570566 (Eastern Bluebird)... ✅ Generated and uploaded
# [656/692] Processing 570310 (Eastern Bluebird)... ✅ Generated and uploaded
# [657/692] Processing 502284 (Eastern Bluebird)... ✅ Generated and uploaded
# [658/692] Processing 502283 (Eastern Bluebird)... ✅ Generated and uploaded
# [659/692] Processing 502282 (Eastern Bluebird)... ✅ Generated and uploaded
# [660/692] Processing 498959 (Eastern Bluebird)... ✅ Generated and uploaded
# [661/692] Processing 481975 (Eastern Bluebird)... ✅ Generated and uploaded
# [662/692] Processing 481623 (Eastern Bluebird)... ✅ Generated and uploaded
# [663/692] Processing 452141 (Eastern Bluebird)... ✅ Generated and uploaded
# [664/692] Processing 452139 (Eastern Bluebird)... ✅ Generated and uploaded
# [665/692] Processing 439868 (Eastern Bluebird)... ✅ Generated and uploaded
# [666/692] Processing 439864 (Eastern Bluebird)... ✅ Generated and uploaded
# [667/692] Processing 420915 (Eastern Bluebird)... ✅ Generated and uploaded
# [668/692] Processing 409000 (Eastern Bluebird)... ✅ Generated and uploaded
# [669/692] Processing 408999 (Eastern Bluebird)... ✅ Generated and uploaded
# [670/692] Processing 408998 (Eastern Bluebird)... ✅ Generated and uploaded
# [671/692] Processing 408997 (Eastern Bluebird)... ✅ Generated and uploaded
# [672/692] Processing 408996 (Eastern Bluebird)... ✅ Generated and uploaded
# [673/692] Processing 408995 (Eastern Bluebird)... ✅ Generated and uploaded
# [674/692] Processing 378953 (Eastern Bluebird)... ✅ Generated and uploaded
# [675/692] Processing 376223 (Eastern Bluebird)... ✅ Generated and uploaded
# [676/692] Processing 367784 (Eastern Bluebird)... ✅ Generated and uploaded
# [677/692] Processing 337449 (Eastern Bluebird)... ✅ Generated and uploaded
# [678/692] Processing 337447 (Eastern Bluebird)... ✅ Generated and uploaded
# [679/692] Processing 301392 (Eastern Bluebird)... ✅ Generated and uploaded
# [680/692] Processing 180252 (Eastern Bluebird)... ✅ Generated and uploaded
# [681/692] Processing 180249 (Eastern Bluebird)... ✅ Generated and uploaded
# [682/692] Processing 179669 (Eastern Bluebird)... ✅ Generated and uploaded
# [683/692] Processing 171698 (Eastern Bluebird)... ✅ Generated and uploaded
# [684/692] Processing 167838 (Eastern Bluebird)... ✅ Generated and uploaded
# [685/692] Processing 150395 (Eastern Bluebird)... ✅ Generated and uploaded
# [686/692] Processing 139431 (Eastern Bluebird)... ✅ Generated and uploaded
# [687/692] Processing 139430 (Eastern Bluebird)... ✅ Generated and uploaded
# [688/692] Processing 137538 (Eastern Bluebird)... ✅ Generated and uploaded
# [689/692] Processing 70120 (Eastern Bluebird)... ✅ Generated and uploaded
# [690/692] Processing 18392 (Eastern Bluebird)... ✅ Generated and uploaded
# [691/692] Processing 18391 (Eastern Bluebird)... ✅ Generated and uploaded
# [692/692] Processing 1374 (Eastern Bluebird)... ✅ Generated and uploaded
#
# ============================================================
# Spectrogram Generation Complete!
# ============================================================
# ✅ Successfully processed: 692
# ⏭️ Skipped (already exists): 0
# ❌ Failed: 0

# %%
# Generate and upload spectrogram metadata

if all_spectrogram_metadata:
    # Create DataFrame
    df_spectrograms = pd.DataFrame(all_spectrogram_metadata)
    
    # Save to temporary files
    csv_path = temp_dir / "spectrograms_metadata.csv"
    json_path = temp_dir / "spectrograms_metadata.json"
    
    # Save CSV
    df_spectrograms.to_csv(csv_path, index=False)
    print(f"✅ Created CSV metadata: {csv_path}")
    
    # Save JSON
    df_spectrograms.to_json(json_path, orient='records', indent=2)
    print(f"✅ Created JSON metadata: {json_path}")
    
    # Upload to S3
    csv_s3_uri = s3_manager.upload_metadata_file(str(csv_path), "spectrograms_metadata")
    json_s3_uri = s3_manager.upload_metadata_file(str(json_path), "spectrograms_metadata")
    
    if csv_s3_uri:
        print(f"✅ Uploaded CSV to S3: {csv_s3_uri}")
    if json_s3_uri:
        print(f"✅ Uploaded JSON to S3: {json_s3_uri}")
    
    # Display summary statistics
    print(f"\n{'='*60}")
    print(f"Spectrogram Dataset Summary")
    print(f"{'='*60}")
    print(f"Total spectrograms: {len(df_spectrograms)}")
    print(f"\nSpectrograms per species:")
    species_counts = df_spectrograms['species_common_name'].value_counts()
    for species, count in species_counts.items():
        print(f"  {species}: {count}")
    
    print(f"\nImage dimensions:")
    print(f"  Average width: {df_spectrograms['image_width'].mean():.0f} pixels")
    print(f"  Average height: {df_spectrograms['image_height'].mean():.0f} pixels")
    print(f"  Width range: {df_spectrograms['image_width'].min()}-{df_spectrograms['image_width'].max()}")
    print(f"  Height range: {df_spectrograms['image_height'].min()}-{df_spectrograms['image_height'].max()}")
    
    print(f"\nSample rate: {df_spectrograms['sample_rate'].iloc[0]} Hz (all recordings)")
    print(f"Total audio duration: {df_spectrograms['duration_seconds'].sum() / 60:.1f} minutes")
    
    # Display first few rows
    print(f"\nSample spectrogram metadata:")
    print(df_spectrograms.head().to_string())
else:
    print("⚠️ No spectrogram metadata to process")
